# %%
import pandas as pd 
import json 
import os
import random
from tqdm import tqdm 
import pickle

# %%
def write_pickle(file_name, content):
    os.makedirs(os.path.dirname(file_name), exist_ok=True)
    with open(file_name, 'wb') as handle:
        pickle.dump(content, handle)

# %%
def read_pickle(file_name):
    with open(file_name, 'rb') as handle:
        return pickle.load(handle)

# %%
def write_json(file_name, content):
    os.makedirs(os.path.dirname(file_name), exist_ok=True)
    with open(file_name, 'w') as outfile:
        json.dump(content, outfile, sort_keys=True, indent=4)

# %%
# Run cell
def read_json_simple(file_name):
    with open(file_name) as json_file:
        data_dict = json.load(json_file)
        return data_dict

# %%
# Run cell
def read_json(file_name):
    with open(file_name) as json_file:
        data_dict = json.load(json_file, object_hook=jsonKeys2int)
        return data_dict

# %%
# Run cell
def jsonKeys2int(x):
    if isinstance(x, dict):
            return {int(k):v for k,v in x.items()}
    return x

# %%
"""
Renaming the columns dataset
"""
df = pd.read_csv("wikigraph_reduced.csv", sep='\t') 
df.columns = ["Edges",'Source', 'Target']

# %%
df.head()
# Out:
#    Edges  Source   Target
# 0    796      95  1185516
# 1    909     108  1059989
# 2    910     108  1062426
# 3    911     108  1161925
# 4   1141     134   541222

# %%
"""
save renamed dataset into a csv file
"""
df.to_csv('data/dataset.csv', index=False)

# %%
"""
Takink as input the file wiki-topcats-page-names.txt, return a Dictionary with key the number of 
the page and as value the name of the page. 
"""

p = open("wiki-topcats-page-names.txt", "r")
pages = {}
for pag in tqdm(p): 
    list_ = pag.split()[1:]
    aux = ' '.join(list_)
    pages[int(pag.split()[0])] = aux
# Out:
# 1791489it [00:05, 300114.83it/s]

# %%
write_pickle('data/pages.pkl', pages)

# %%
pag
# Out:
# {0: 'Chiasmal syndrome',
#  1: 'Kleroterion',
#  2: 'Pinakion',
#  3: 'LyndonHochschildSerre spectral sequence',
#  4: "Zariski's main theorem",
#  5: 'FultonHansen connectedness theorem',
#  6: "Cayley's ruled cubic surface",
#  7: 'Annulus theorem',
#  8: "Bing's recognition theorem",
#  9: 'BochnerMartinelli formula',
#  10: 'BergmanWeil formula',
#  11: 'Menallen Township, Pennsylvania',
#  12: 'Missouri Route 117',
#  13: 'Jadwin, Missouri',
#  14: 'Gladden, Missouri',
#  15: 'Missouri Route 119',
#  16: 'Missouri Route 68',
#  17: 'Sligo, Missouri',
#  18: 'Lower Parker School',
#  19: 'Lecoma, Missouri',
#  20: 'Doss, Missouri',
#  21: 'Boss, Missouri',
#  22: 'Vulcan, Missouri',
#  23: 'Glover, Missouri',
#  24: 'Missouri Route 114',
#  25: 'Missouri Route 12',
#  26: 'Missouri Route 80',
#  27: 'Missouri Route 75',
#  28: 'Missouri Route 91',
#  29: 'Missouri Route 147',
#  30: 'Missouri Route 149',
#  31: 'Goldsberry, Missouri',
#  32: 'Missouri Route 162',
#  33: 'Missouri Route 172',
#  34: 'Missouri Route 245',
#  35: 'Missouri Route 273',
#  36: 'Missouri Route 350',
#  37: 'Arkansas Highway 99',
#  38: 'Missouri Route 131',
#  39: 'Missouri Route 20',
#  40: 'Missouri Route 112',
#  41: 'Missouri Route 126',
#  42: 'Preston Overlook',
#  43: 'Minnesota State Highway 139',
#  44: 'Missouri Route 185',
#  45: 'U.S. Route 166',
#  46: 'List of Missouri highways',
#  47: 'Missouri Route 92',
#  48: 'Missouri Route 168',
#  49: 'Missouri Route 176',
#  50: 'Missouri Route 77',
#  51: 'Tabilk railway station',
#  52: 'Hung Huang',
#  53: 'Brocken Transmitter',
#  54: 'Casablanca Twin Center',
#  55: 'Adrenaline Rush (film)',
#  56: 'Cathedral of St Louis, Plovdiv',
#  57: 'Kamen Petkov',
#  58: 'St Paul of the Cross Cathedral',
#  59: 'Abbar',
#  60: 'Al-Ghurair Group',
#  61: 'Redemptive Film Festival',
#  62: 'Richard Cytowic',
#  63: 'UK Synaesthesia Association',
#  64: 'Cretien van Campen',
#  65: 'University of South Florida Herd of Thunder',
#  66: 'James Wannerton',
#  67: 'Basement show',
#  68: 'Guerrilla punk',
#  69: 'Guerrilla gig',
#  70: 'Marissa Paternoster',
#  71: 'Screaming Females',
#  72: 'Don Giovanni Records',
#  73: 'JEFF the Brotherhood',
#  74: 'Ty Segall',
#  75: 'KDOV',
#  76: 'Julian, North Carolina',
#  77: 'E.C. Walker',
#  78: 'Bona, Missouri',
#  79: 'Dick Thoenen',
#  80: 'Thompson, Missouri',
#  81: 'Missouri Route 151',
#  82: 'Missouri Route 22',
#  83: 'Winigan, Missouri',
#  84: 'Missouri Route 103',
#  85: '13th century in literature',
#  86: 'Horace Rowan Gaither',
#  87: 'Gaither Report',
#  88: 'Enzyme potentiated desensitization',
#  89: 'Kagenna Magazine',
#  90: 'Vula',
#  91: 'MANAS Journal',
#  92: 'Henry Geiger',
#  93: 'Land and liberty (slogan)',
#  94: 'John Levy (philosopher)',
#  95: 'This Way (Hana Pestle album)',
#  96: 'Alan Diaz',
#  97: 'Geordie Hormel',
#  98: 'Frank Twedell',
#  99: 'Anarchy in Somalia',
#  100: 'National Library of Somalia',
#  101: 'Don Li (composer/musician)',
#  102: 'Direct Action to Stop the War',
#  103: 'Steve McDonald (Celtic music)',
#  104: 'Jeff McDonald',
#  105: 'Robert Hecker',
#  106: 'Third Eye (Redd Kross album)',
#  107: 'Steven Shane McDonald',
#  108: 'Born Innocent (Redd Kross album)',
#  109: 'Teen Babes from Monsanto',
#  110: "Live at Maxwell's",
#  111: 'Imperial Teen',
#  112: 'Aim and Ignite',
#  113: 'Seasick (album)',
#  114: 'Jessica Keen',
#  115: 'Aaron Seltzer',
#  116: 'Bryan Pata',
#  117: 'Ken Clark (running back)',
#  118: 'Ben Rudolph',
#  119: 'Dean Miraldi',
#  120: 'Lynn Hoyem',
#  121: 'Russ Bolinger',
#  122: 'Mark Seay',
#  123: 'Leon Burns',
#  124: 'Shane Curry',
#  125: 'Thomas Herrion',
#  126: 'Ben H. Lewis',
#  127: 'List of mayors of Riverside, California',
#  128: 'Twin Towers Correctional Facility',
#  129: 'Imperial Dynasty restaurant',
#  130: 'Burro Schmidt Tunnel',
#  131: 'General Mining Act of 1872',
#  132: 'Soul On Ice',
#  133: 'Theodore Hamm',
#  134: 'San Quentin (1937 film)',
#  135: 'Schlitzie',
#  136: 'Ward Morehouse (activist)',
#  137: 'Ward Morehouse',
#  138: 'Jean Dalrymple',
#  139: 'Philadelphia Anti-Graffiti Network',
#  140: 'Jane Golden',
#  141: 'Mural Arts Program',
#  142: 'Nova Color Artists Acrylic Paint',
#  143: 'Federal Trade Commission v. Sperry & Hutchinson Trading Stamp Co.',
#  144: 'Philip Grosser',
#  145: 'Stephen Rosskamm Shalom',
#  146: 'Frederic Ewen',
#  147: 'George Clancy',
#  148: 'Pharmaceutical lobby',
#  149: 'Japan Marine Accident Inquiry Agency',
#  150: "Alabama's 10th congressional district",
#  151: 'WVTS-FM',
#  152: 'David L. Eubanks',
#  153: '35 and Ticking',
#  154: 'Luenell',
#  155: 'Bill Neill',
#  156: 'McKay McKinnon',
#  157: 'Jay F. W. Pearson',
#  158: 'Edward T. Foote II',
#  159: 'Alexander Wolff',
#  160: 'Steven Grosby',
#  161: 'Quasiperiodicity',
#  162: 'Quasiperiodic motion',
#  163: 'Michael Jger',
#  164: 'Pennsylvania Route 449',
#  165: 'Pennsylvania Route 244',
#  166: 'Mark Clifford',
#  167: 'Donna Dubinsky',
#  168: 'Invacare',
#  169: 'Sarver, Pennsylvania',
#  170: 'Kirk Cox',
#  171: 'Robert Louden',
#  172: 'SS Sultana',
#  173: 'Walls of Glass',
#  174: 'Don Brockett',
#  175: 'NPDGamma',
#  176: 'Mycobacterium Tuberculosis Structural Genomics Consortium',
#  177: 'Hurwitz polynomial',
#  178: 'Derivation of the Routh array',
#  179: 'Routhian',
#  180: 'Separation principle',
#  181: 'Orbit (control theory)',
#  182: "Krener's theorem",
#  183: 'Singular control',
#  184: 'Neil Foley',
#  185: 'Down in the Boondocks (album)',
#  186: 'Cherry Hill Park (album)',
#  187: 'Champagne Jam',
#  188: 'A Rock and Roll Alternative',
#  189: 'Quinella (album)',
#  190: 'Atlanta Rhythm Section (album)',
#  191: 'Back Up Against the Wall',
#  192: 'Third Annual Pipe Dream',
#  193: 'Dog Days (Atlanta Rhythm Section album)',
#  194: 'Red Tape (album)',
#  195: 'Buddy Buie',
#  196: 'Bent Faurschou-Hviid',
#  197: 'Reparata and the Delrons',
#  198: 'WriteGirl',
#  199: 'Lady Flash',
#  200: 'Agricultural Museum (periodical)',
#  201: 'Microwave News',
#  202: 'North Carolina Highway 411',
#  203: 'North Carolina Highway 41',
#  204: 'Phillip Swann',
#  205: 'Missouri Route 370',
#  206: 'If It Was Easy',
#  207: 'Bertram Tracy Clayton',
#  208: 'Israel F. Fischer',
#  209: 'Eric "Red Mouth" Gebhardt',
#  210: 'The Studdogs',
#  211: 'Charles Borromeo McLaughlin',
#  212: 'Michael Gunther',
#  213: 'I Remember You Now...',
#  214: 'The Honeytrap',
#  215: 'Marissa Mazzola-McMahon',
#  216: 'Widdowson Group',
#  217: 'SeaWorld SkyTower',
#  218: '55 West on the Esplanade',
#  219: 'The Vue at Lake Eola',
#  220: 'Solaire at the Plaza',
#  221: 'The Peabody Orlando',
#  222: 'James Joseph (American football)',
#  223: 'The Negro in the South',
#  224: 'The Future of the American Negro',
#  225: 'Working With the Hands',
#  226: 'Vance Mueller',
#  227: 'Edward Young Clarke',
#  228: 'M. K. Turk',
#  229: 'William Anderson Handley',
#  230: 'Oliver C. Wiley',
#  231: 'Loraine, California',
#  232: 'Desmoglein',
#  233: 'Pemphigus foliaceus',
#  234: 'Antonio Travi',
#  235: 'Robin T. Cotton',
#  236: 'Alexander von Winiwarter',
#  237: 'Virchow-Robin spaces',
#  238: 'Patent Blue V',
#  239: 'Congenital lymphedema',
#  240: 'Accredited Crane Operator Certification',
#  241: 'John Duncanson',
#  242: 'Pneumotaxic center',
#  243: 'Niels Bjerrum',
#  244: 'Great Jones Street (novel)',
#  245: 'Running Dog',
#  246: 'Amazons (novel)',
#  247: 'Americana (novel)',
#  248: 'The Names',
#  249: 'Falling Man (novel)',
#  250: 'Point Omega',
#  251: 'The Body Artist',
#  252: 'Captain Confederacy',
#  253: 'The Colour (novel)',
#  254: 'Time and Withering',
#  255: 'American Beetles',
#  256: 'Michael C. Thomas',
#  257: 'Ross H. Arnett, Jr.',
#  258: 'Euhrychiopsis lecontei',
#  259: 'Rhysodidae',
#  260: 'Hypermetamorphosis',
#  261: 'Cantharidin',
#  262: 'Spanish fly',
#  263: 'Meloe proscarabaeus',
#  264: 'Spanish Fly (2003 film)',
#  265: 'Ethnoentomology',
#  266: 'Robert Matheson',
#  267: 'Urogenital tuberculosis',
#  268: 'Drilus flavescens',
#  269: 'Omalisus fontisbellaquaei',
#  270: 'Omalisidae',
#  271: 'Raspberry beetle',
#  272: 'Hister quadrimaculatus',
#  273: 'Biphyllidae',
#  274: 'Byturidae',
#  275: 'Geotrupes stercorarius',
#  276: 'Glowworm',
#  277: 'Rhagophthalmidae',
#  278: 'Phengodidae',
#  279: 'Bolitophilidae',
#  280: 'Orfelia fultoni',
#  281: 'Mycetophilidae',
#  282: 'Diadocidiidae',
#  283: 'Ditomyiidae',
#  284: 'Lampyris noctiluca',
#  285: 'Lycidae',
#  286: 'Firefly',
#  287: 'Lampyridae',
#  288: 'Photinus carolinus',
#  289: 'Cerophytidae',
#  290: 'Bothrideridae',
#  291: 'Trogossitidae',
#  292: 'Erotylidae',
#  293: 'Anthaxia thalassophila',
#  294: 'Coraebus elatus',
#  295: 'Buprestis splendens',
#  296: 'Anthaxia nitidula',
#  297: 'Acmaeoderella flavofasciata',
#  298: 'Coraebus rubi',
#  299: 'Phalacridae',
#  300: 'Anthaxia scutellaris',
#  301: 'Philanthaxia',
#  302: 'Schizopus',
#  303: 'Schizopodidae',
#  304: 'Electrapate',
#  305: 'Dystaxia (genus)',
#  306: 'Glyptoscelimorpha',
#  307: 'Galbella',
#  308: 'Acmaeoderella',
#  309: 'Barakula',
#  310: 'Euchroma',
#  311: 'Anilara',
#  312: 'Anthaxia',
#  313: 'Chalcophora',
#  314: 'Perotis (beetle)',
#  315: 'Buprestinae',
#  316: 'Hovorigenium',
#  317: 'Castiarina',
#  318: 'Conognatha',
#  319: 'Epistomentis',
#  320: 'Exagistus',
#  321: 'Julodimorpha',
#  322: 'Pseudactenodes',
#  323: 'Tetragonoschema',
#  324: 'Trachypteris',
#  325: 'Trigonogenium',
#  326: 'Brachyspathus',
#  327: 'Trichinorhipis',
#  328: 'Merimna',
#  329: 'Metaxymorpha',
#  330: 'Panapulla',
#  331: 'Peronaemis',
#  332: 'Eolampra',
#  333: 'Chalcangium',
#  334: 'Karenaxia',
#  335: 'Archeobuprestis',
#  336: 'Nascio (genus)',
#  337: 'Agaeocera',
#  338: 'Anthaxioides',
#  339: 'Brachanthaxia',
#  340: 'Buprestina',
#  341: 'Calotemognatha',
#  342: 'Ceylonaxia',
#  343: 'Chalcogenia',
#  344: 'Chrysobothris',
#  345: 'Cimrmanium',
#  346: 'Colobogaster',
#  347: 'Cylindrophora',
#  348: 'Cyrioxus',
#  349: 'Embrikiola',
#  350: 'Mendizabalia',
#  351: 'Melobasis',
#  352: 'Neocuris',
#  353: 'Philandia',
#  354: 'Pterobothris',
#  355: 'Selagis',
#  356: 'Theryaxia',
#  357: 'Xenomelanophila',
#  358: 'Zulubuprestis',
#  359: 'Illolampra',
#  360: 'Lomatus',
#  361: 'Bubastoides',
#  362: 'Stephansortia',
#  363: 'Metabuprestium',
#  364: 'Balthasarella',
#  365: 'Coomaniella',
#  366: 'Hoscheckia',
#  367: 'Knowltonia (insect)',
#  368: 'Megactenodes',
#  369: 'Melanophila',
#  370: 'Pseudhyperantha',
#  371: 'Roswitha (genus)',
#  372: 'Sphaerobothris',
#  373: 'Trachykele',
#  374: 'Araucariana',
#  375: 'Paractenodes',
#  376: 'Agrilaxia',
#  377: 'Semiognatha',
#  378: 'Bilyaxia',
#  379: 'Lobites',
#  380: 'Brevista',
#  381: 'Buprestites',
#  382: 'Madessetia',
#  383: 'Actenodes',
#  384: 'Hiperantha',
#  385: 'Spectralia',
#  386: 'Parastrigulia',
#  387: 'Holubia',
#  388: 'Brasilaxia',
#  389: 'Paraphrixia',
#  390: 'Phrixia',
#  391: 'Eudiana',
#  392: 'Kisanthobia',
#  393: 'Notographus',
#  394: 'Oaxacanthaxia',
#  395: 'Romanophora',
#  396: 'Strandiola',
#  397: 'Glaphyroptera',
#  398: 'Pseudothyrea',
#  399: 'Kurosawaia',
#  400: 'Cyrioides',
#  401: 'Maoraxia',
#  402: 'Notobubastes',
#  403: 'Pygicera',
#  404: 'Xenorhipis',
#  405: 'Philanthaxoides',
#  406: 'Afagrilaxia',
#  407: 'Phaenops (genus)',
#  408: 'Senegalisia',
#  409: 'Polyonychus',
#  410: 'Madecorformica',
#  411: 'Afrabothris',
#  412: 'Anthaxoschema',
#  413: 'Aristosoma',
#  414: 'Belionota',
#  415: 'Ctenoderus',
#  416: 'Hesperorhipis',
#  417: 'Juniperella',
#  418: 'Lamprocheila',
#  419: 'Lasionota',
#  420: 'Mixochlorus',
#  421: 'Neobuprestis',
#  422: 'Pseudanilara',
#  423: 'Sinokele',
#  424: 'Stigmodera',
#  425: 'Thomassetia',
#  426: 'Pseudophlocteis',
#  427: 'Andakhudukia',
#  428: 'Jurabuprestis',
#  429: 'Mesostigmodera',
#  430: 'Micranthaxia',
#  431: 'Protogenia',
#  432: 'Agriloides',
#  433: 'Alissoderus',
#  434: 'Amyia',
#  435: 'Anodontodora',
#  436: 'Aphanisticus',
#  437: 'Borneoscelus',
#  438: 'Brachycoraebus',
#  439: 'Callipyndax',
#  440: 'Capitijubatus',
#  441: 'Chalcophlocteis',
#  442: 'Cobosietta',
#  443: 'Coraebastus',
#  444: 'Paracylindromorphus',
#  445: 'Cupriscobina',
#  446: 'Cylindromorphoides',
#  447: 'Cyphothroax',
#  448: 'Demostis',
#  449: 'Diadora (genus)',
#  450: 'Diadorina',
#  451: 'Dinocephalia (insect)',
#  452: 'Dinocoroebus',
#  453: 'Diphucrania',
#  454: 'Discoderes',
#  455: 'Discoderopsis',
#  456: 'Dismorpha',
#  457: 'Dorochoviella',
#  458: 'Endelomorphus',
#  459: 'Endelus',
#  460: 'Coraebus',
#  461: 'Dejongiella',
#  462: 'Deyrollius',
#  463: 'Amorphosoma',
#  464: 'Antanambia',
#  465: 'Bergidora',
#  466: 'Cantoniellus',
#  467: 'Coraebina',
#  468: 'Autarcontes',
#  469: 'Duncanius',
#  470: 'Asymades',
#  471: 'Cylindromorphus',
#  472: 'Coraebosoma',
#  473: 'Pseudoclema',
#  474: 'Taphrocerus',
#  475: 'Afrocylindromorphus',
#  476: 'Agrilochyseus',
#  477: 'Chloricala',
#  478: 'Cryptomorpha',
#  479: 'Discoderella',
#  480: 'Bourgoinia',
#  481: 'Angatra',
#  482: 'Agrilinae',
#  483: 'Nelsonagrilus',
#  484: 'Eumorphocerus',
#  485: 'Metasambus',
#  486: 'Obenbergerula',
#  487: 'Pachyschelus',
#  488: 'Gigantocoreabus',
#  489: 'Mychommatus',
#  490: 'Pachycisseis',
#  491: 'Cryptodactylus',
#  492: 'Leiopleura',
#  493: 'Euamyia',
#  494: 'Eumerophilus',
#  495: 'Habroloma',
#  496: 'Meliacanthus',
#  497: 'Neefia',
#  498: 'Nickerleola',
#  499: 'Parasambus',
#  500: 'Philippscelus',
#  501: 'Philocoroebus',
#  502: 'Sambomorpha',
#  503: 'Seranambia',
#  504: 'Strandietta',
#  505: 'Strigulioides',
#  506: 'Trypantius',
#  507: 'Velutia',
#  508: 'Xenomerius',
#  509: 'Zitella',
#  510: 'Belgaumia',
#  511: 'Pareumerus',
#  512: 'Phlocteis',
#  513: 'Epimacha',
#  514: 'Niehuisia',
#  515: 'Ethiopoeus',
#  516: 'Helferia',
#  517: 'Lumawigia',
#  518: 'Nalanda (genus)',
#  519: 'Neotrachys',
#  520: 'Omochyseus',
#  521: 'Sjoestedtius',
#  522: 'Meliboeus',
#  523: 'Eudiadora',
#  524: 'Franchieta',
#  525: 'Heromorphus',
#  526: 'Maublancia (insect)',
#  527: 'Neotoxoscelus',
#  528: 'Sakalianus',
#  529: 'Ethonion',
#  530: 'Euchroaria',
#  531: 'Eulasiodora',
#  532: 'Eupristocerus',
#  533: 'Eurynodes',
#  534: 'Evimantius',
#  535: 'Falliellus',
#  536: 'Geralius',
#  537: 'Gracilocala',
#  538: 'Holmerika',
#  539: 'Hylaeogena',
#  540: 'Hypocisseis',
#  541: 'Indiadactylus',
#  542: 'Ivalouwayneia',
#  543: 'Kamosia',
#  544: 'Kamosiella',
#  545: 'Katangiella',
#  546: 'Katonia',
#  547: 'Kerremansella',
#  548: 'Kerremansia',
#  549: 'Lakhonia',
#  550: 'Lius',
#  551: 'Madaphlocteis',
#  552: 'Malawiella',
#  553: 'Mandritsaria',
#  554: 'Maroantsetra (genus)',
#  555: 'Melanocoraebus',
#  556: 'Melibaeopsis',
#  557: 'Meliboeithon',
#  558: 'Midongya',
#  559: 'Neefioides',
#  560: 'Neocoraebus',
#  561: 'Neospades',
#  562: 'Paracephala',
#  563: 'Parademostis',
#  564: 'Paradora',
#  565: 'Paradorella',
#  566: 'Paragrilus',
#  567: 'Paranastella',
#  568: 'Paraxenita',
#  569: 'Peyrierasina',
#  570: 'Planidia (genus)',
#  571: 'Promeliboeus',
#  572: 'Pseudagrilus',
#  573: 'Pseudocoraebus',
#  574: 'Pseudokerremansia',
#  575: 'Sambirania',
#  576: 'Seyrigia',
#  577: 'Shimogia',
#  578: 'Sibuyanella',
#  579: 'Strigulia',
#  580: 'Suarezia (beetle)',
#  581: 'Synechocera',
#  582: 'Therybupestris',
#  583: 'Vanroonia',
#  584: 'Wendleria',
#  585: 'Xenita',
#  586: 'Agrilozodes',
#  587: 'Brachelytrium',
#  588: 'Bubastes',
#  589: 'Diadoxus',
#  590: 'Euryspilus',
#  591: 'Hilarotes',
#  592: 'Microcastalia',
#  593: 'Nascioides',
#  594: 'Neobubastes',
#  595: 'Paracuris',
#  596: 'Anaphlocteis',
#  597: 'Camerunadora',
#  598: 'Australorhipis',
#  599: 'Calodema',
#  600: 'Ditriaena',
#  601: 'Jakovleviola',
#  602: 'Buprestidae',
#  603: 'Buprestoidea',
#  604: 'Kzylordyina',
#  605: 'Archepsila',
#  606: 'Agrilodia',
#  607: 'Amorphosternoides',
#  608: 'Anadora',
#  609: 'Anocisseis',
#  610: 'Ausralodraco',
#  611: 'Bellamyus',
#  612: 'Cantonius',
#  613: 'Clema',
#  614: 'Compsoglypha',
#  615: 'Dessumia',
#  616: 'Malagascoderes',
#  617: 'Discoderoides',
#  618: 'Entomogaster',
#  619: 'Callimicra',
#  620: 'Cisseicoraebus',
#  621: 'Brachydora',
#  622: 'Brachys',
#  623: 'Mundaria',
#  624: 'Rhaeboscelis',
#  625: 'Toxoscelus',
#  626: 'Germarica',
#  627: 'Pseudokamosia',
#  628: 'Helferina',
#  629: 'Jaroslavia',
#  630: 'Lepidoclema',
#  631: 'Nastella',
#  632: 'Pseudagrilodes',
#  633: 'Sambus',
#  634: 'Sarawakita',
#  635: 'Stanwatkinsius',
#  636: 'Taphroceroides',
#  637: 'Tonkinula',
#  638: 'Trachys (insect)',
#  639: 'Eurythyrea',
#  640: 'Achardella',
#  641: 'Afrophorella',
#  642: 'Agelia',
#  643: 'Asidoptera',
#  644: 'Barrellus',
#  645: 'Bojaskinskia',
#  646: 'Chalcophoropsis',
#  647: 'Chlorophorella',
#  648: 'Demochroa',
#  649: 'Genestia',
#  650: 'Gyascutus (insect)',
#  651: 'Halecia',
#  652: 'Haplotrinchus',
#  653: 'Icarina',
#  654: 'Melobasina',
#  655: 'Micropistus',
#  656: 'Monosacra',
#  657: 'Nipponobuprestis',
#  658: 'Philocteanus',
#  659: 'Poecilonota',
#  660: 'Pseudocallopistus',
#  661: 'Pseudolampetis',
#  662: 'Psiloptera',
#  663: 'Rhabdolona',
#  664: 'Rooniella',
#  665: 'Sphenoptera',
#  666: 'Tokaranodicera',
#  667: 'Pseudalecia',
#  668: 'Chrysopistus',
#  669: 'Ectinogonia',
#  670: 'Cardiaspis',
#  671: 'Chalcoplia',
#  672: 'Chalcopoecila',
#  673: 'Cyphogastra',
#  674: 'Cyalithus',
#  675: 'Ulaikoilia',
#  676: 'Zoolrecordia',
#  677: 'Westcottia',
#  678: 'Astraeus (beetle)',
#  679: 'Cochinchinula',
#  680: 'Odettea',
#  681: 'Cretothyrea',
#  682: 'Lepismadora',
#  683: 'Pilotrulleum',
#  684: 'Bulis',
#  685: 'Jelinekia',
#  686: 'Micropolycesta',
#  687: 'Ancylotela',
#  688: 'Paracmaeoderoides',
#  689: 'Bordonia',
#  690: 'Brachmaeodera',
#  691: 'Pseudotrigonogya',
#  692: 'Theryola',
#  693: 'Ptosima',
#  694: 'Sommaia',
#  695: 'Polycesta',
#  696: 'Pseudocastalia',
#  697: 'Fuesslinia',
#  698: 'Amorphosternus',
#  699: 'Anthaxomorphus',
#  700: 'Parakamosia',
#  701: 'Aglaostola',
#  702: 'Torresita',
#  703: 'Buprestis',
#  704: 'Cyphosoma',
#  705: 'Vadonaxia',
#  706: 'Afrochroa',
#  707: 'Ampheremus',
#  708: 'Asemochrysus',
#  709: 'Austrochalcophora',
#  710: 'Baudonisia',
#  711: 'Capnodis',
#  712: 'Catoxantha',
#  713: 'Chalcophorella',
#  714: 'Cinyra',
#  715: 'Cordillerita',
#  716: 'Descarpentriesiola',
#  717: 'Dicerca',
#  718: 'Dicercomorpha',
#  719: 'Euplectalecia',
#  720: 'Hypoprasis',
#  721: 'Iridotaenia',
#  722: 'Kolleria',
#  723: 'Metataenia',
#  724: 'Nesotrinchus',
#  725: 'Oedisterna',
#  726: 'Paracupta',
#  727: 'Paratassa',
#  728: 'Pelecopselaphus',
#  729: 'Periorisma',
#  730: 'Polybothris',
#  731: 'Prasinalia',
#  732: 'Pseudoperotis',
#  733: 'Pseudotaenia',
#  734: 'Sapaia',
#  735: 'Steraspis',
#  736: 'Strandissa',
#  737: 'Touzalinia',
#  738: 'Chalcophorotaenia',
#  739: 'Epidelus',
#  740: 'Chrysesthes',
#  741: 'Madecassia',
#  742: 'Scaptelytra',
#  743: 'Embrikilium',
#  744: 'Eupodalecia',
#  745: 'Lamprodila',
#  746: 'Parataenia',
#  747: 'Semenoviella',
#  748: 'Lampetis',
#  749: 'Apateum',
#  750: 'Asamia',
#  751: 'Chrysaspis (insect)',
#  752: 'Eucallopistus',
#  753: 'Fahraeusia',
#  754: 'Hippomelas',
#  755: 'Holynskirbus',
#  756: 'Latipalpis',
#  757: 'Megaloxantha',
#  758: 'Nanularia',
#  759: 'Phelix (genus)',
#  760: 'Pygichaeta',
#  761: 'Saundersina',
#  762: 'Texania',
#  763: 'Armenosoma',
#  764: 'Bellamyclus',
#  765: 'Tamamushia',
#  766: 'Chrysochroinae',
#  767: 'Chrysodema',
#  768: 'Austrophorella',
#  769: 'Julodinae',
#  770: 'Julodella',
#  771: 'Amblysterna',
#  772: 'Julodis',
#  773: 'Neojulodis',
#  774: 'Microjulodis',
#  775: 'Helferella',
#  776: 'Nothomorphoides',
#  777: 'Paraancylotela',
#  778: 'Paratyndaris',
#  779: 'Parapolycesta',
#  780: 'Madecastalia',
#  781: 'Polycestaxis',
#  782: 'Thurntaxisia',
#  783: 'Pseudopolycesta',
#  784: 'Bellamyina',
#  785: 'Blepharum',
#  786: 'Madecacesta',
#  787: 'Ocypetes',
#  788: 'Xenopsis',
#  789: 'Aldabrica',
#  790: 'Paracastalia',
#  791: 'Cobosella',
#  792: 'Microacmaeodera',
#  793: 'Neopolycesta',
#  794: 'Chrysophana',
#  795: 'Exaesthetus',
#  796: 'Schoutedeniastes',
#  797: 'Thrincopyge',
#  798: 'Bilyesta',
#  799: 'Cobosesta',
#  800: 'Paratrachys',
#  801: 'Acmaeoderoides',
#  802: 'Nothomorpha',
#  803: 'Polycestinae',
#  804: 'Acmaeodera',
#  805: 'Polycestella',
#  806: 'Beerellus',
#  807: 'Mastogenius',
#  808: 'Micrasta',
#  809: 'Polycestis',
#  810: 'Pseudacherusia',
#  811: 'Xantheremia',
#  812: 'Agenjosiana',
#  813: 'Ankareus',
#  814: 'Atacamita',
#  815: 'Kurosawaxia',
#  816: 'Mimicoclytrina',
#  817: 'Neomastogenius',
#  818: 'Tyndarimorpha',
#  819: 'Tyndaris (genus)',
#  820: 'Xyroscelis',
#  821: 'Sponsor (genus)',
#  822: 'Strigopteroides',
#  823: 'Thaichinula',
#  824: 'Hayekina',
#  825: 'Namibogenius',
#  826: 'Acmaeoderopsis',
#  827: 'Anambodera',
#  828: 'Hiperleptodema',
#  829: 'Kogania',
#  830: 'Neocypetes',
#  831: 'Perucola',
#  832: 'Polycestaxia',
#  833: 'Polycestina',
#  834: 'Pelycothorax',
#  835: 'Richtersveldia',
#  836: 'Siamastogenius',
#  837: 'Strigoptera',
#  838: 'Polycestoides',
#  839: 'Prospheres',
#  840: 'Trigonogya',
#  841: 'Parathyreinae',
#  842: 'Evides',
#  843: 'John Paget Figg-Hoblyn',
#  844: 'Agrilus hyperici',
#  845: 'George Marsham',
#  846: 'Reiter (disambiguation)',
#  847: 'Michael Reiter',
#  848: 'Reitter',
#  849: 'Dermestidae',
#  850: 'Derodontidae',
#  851: 'List of beetles of Great Britain',
#  852: 'Varied carpet beetle',
#  853: 'Oryzaephilus surinamensis',
#  854: 'Korynetes caeruleus',
#  855: 'Anobiidae',
#  856: 'Ptinus fur',
#  857: 'Khapra beetle',
#  858: 'Bostrychoplites cornutus',
#  859: 'Rhyzopertha dominica',
#  860: 'Dinoderus minutus',
#  861: 'Bostrichidae',
#  862: 'Takabuti',
#  863: 'Agrilus viridis',
#  864: 'Mona monkey',
#  865: 'Hermann Fol',
#  866: 'Observatoire Oceanologique de Villefranche',
#  867: 'John Karl Hillers',
#  868: 'Cissa (genus)',
#  869: 'Gonepteryx aspasia',
#  870: 'Abraham Neuda',
#  871: "Revue de l'Orient Latin",
#  872: 'William Doyle (historian)',
#  873: 'Oxford History of the French Revolution',
#  874: 'James Duncan (zoologist)',
#  875: 'L. S. Stepanyan',
#  876: 'Panorpa communis',
#  877: 'Motherisk',
#  878: 'Canadian Mothercraft Society',
#  879: 'Single-strand binding protein',
#  880: 'Netropsin',
#  881: 'Lexitropsin',
#  882: 'Local anesthetic with vasoconstrictor',
#  883: 'Co-codaprin',
#  884: 'Co-dydramol',
#  885: 'Rotational partition function',
#  886: 'CACNG2',
#  887: 'Haile Debas',
#  888: 'IGEM',
#  889: 'Polymerase cycling assembly',
#  890: 'Porcine Reproductive and Respiratory Syndrome Virus',
#  891: 'Lactate dehydrogenase elevating virus',
#  892: 'Equine viral arteritis',
#  893: 'Simian hemorrhagic fever virus',
#  894: '2009 flu pandemic',
#  895: '2009 flu pandemic in the United States',
#  896: 'List of Savage Lovecast episodes',
#  897: 'The Annotated Turing',
#  898: 'Divinylcyclopropane-cycloheptadiene rearrangement',
#  899: 'Canavanine',
#  900: 'Sodium ferulate',
#  901: 'Shennong Ben Cao Jing',
#  902: 'Cistanche',
#  903: 'Alpha oxidation',
#  904: 'Chemical specificity',
#  905: 'Clinical Global Impression',
#  906: 'Tripartite motif family',
#  907: 'ZNF10',
#  908: 'TRIM28',
#  909: 'TRIM33',
#  910: 'TRIM24',
#  911: 'Krppel',
#  912: 'Group-specific antigen',
#  913: 'F2RL1',
#  914: 'Kostmann syndrome',
#  915: 'Lagochilin',
#  916: 'Quassin',
#  917: 'Bilious vomiting syndrome',
#  918: 'Metiamide',
#  919: 'Conessine',
#  920: 'Desmoplakin',
#  921: 'Naxos syndrome',
#  922: 'Nephrin',
#  923: 'Cadherin cytoplasmic region',
#  924: 'Dithiocarbamate',
#  925: 'West End (London)',
#  926: 'ENTH domain',
#  927: 'Oxanion hole',
#  928: 'Lasse Simonsen',
#  929: 'Atrial syncytium',
#  930: 'Ventricular syncytium',
#  931: 'Igor Melyakov',
#  932: 'Obsolescence',
#  933: 'English Mistery',
#  934: 'Amco',
#  935: 'Gina Ford',
#  936: 'Claire Verity',
#  937: 'Allison Lynn',
#  938: 'Cynthia Lynn',
#  939: 'Salt substitute',
#  940: 'E.Stonji',
#  941: 'Deinococcus',
#  942: 'Bicinchoninic acid assay',
#  943: 'Theodore Gray',
#  944: 'Diisopropylamine',
#  945: 'Potassium bis(trimethylsilyl)amide',
#  946: 'Laboratory centrifuge',
#  947: 'Solomon Carter Fuller',
#  948: 'Tyler Cymet',
#  949: '1,1,2,2-Tetrachloroethane',
#  950: 'Intermediate trophoblast',
#  951: 'Infundibular recess',
#  952: 'Dinesh Kumar Gupta',
#  953: 'Shivaji Sawant',
#  954: 'BCL11B',
#  955: 'BCL11A',
#  956: 'Emerin',
#  957: 'ACTG2',
#  958: 'Pre-integration complex',
#  959: 'Vpr',
#  960: 'Gag/pol translational readthrough site',
#  961: 'Ty5 retrotransposon',
#  962: 'Cytoplasmic inclusion',
#  963: 'John Magno',
#  964: 'Alex Magno (choreographer)',
#  965: 'Scheie syndrome',
#  966: 'Catamnesis',
#  967: 'Historian (medical)',
#  968: 'Acetonedicarboxylic acid',
#  969: 'Morbid map',
#  970: 'Retrospective cohort study',
#  971: 'Friction burn',
#  972: '7-Dehydrocholesterol',
#  973: 'Freckle',
#  974: 'Ocular micrometer',
#  975: 'Condoms, needles, and negotiation',
#  976: 'Crack the Whip',
#  977: 'Floppy trunk syndrome',
#  978: 'Occipital neuralgia',
#  979: 'Kirk Francis',
#  980: 'Zelda Harris',
#  981: 'The Piano Lesson (film)',
#  982: 'Reber (automobile)',
#  983: 'Acme (automobile)',
#  984: 'Weakness (EP)',
#  985: 'Propanidid',
#  986: 'Rieke metals',
#  987: 'Linker DNA',
#  988: 'Cellcell interaction',
#  989: 'KAL1 gene',
#  990: 'Anosmin-1',
#  991: 'Bovine leukemia virus',
#  992: 'Mason-Pfizer monkey virus packaging signal',
#  993: 'Bovine leukaemia virus RNA packaging signal',
#  994: 'Wieland-Gumlich aldehyde',
#  995: 'Sir William Arbuthnot-Lane, 1st Baronet',
#  996: 'Lelord Kordel',
#  997: 'Fraser syndrome',
#  998: 'BACH2',
#  999: 'HMGA1',
#  ...}

# %%
pag  = read_pickle('data/pages.pkl')

# %%
"""
Saving the first dict
"""
write_json('data/pages.json', pages)

# %%
voc = read_json('data/pages.json')

# %%
"""
Return 2 dicts:
1. The inverted has as key an integer from 0 to the len of the element in the file
and as value the number of the article that appears in the category. 
2. The 
"""
cat = open("wiki-topcats-categories.txt", "r")
categories_inv = {}
inverted = {}
categories = {}
count = 0 
for i in tqdm(cat): 
    category = i.split()[0][9:-1]
    page_in_cat = list(map(int, i.split()[1:])) 
    categories_inv[count]= category
    inverted[count] = page_in_cat
    categories[category] = page_in_cat
    count += 1
# Out:
# 17364it [00:02, 8527.08it/s]

# %%
write_pickle('data/categories.pkl', categories)

# %%
categories  = read_pickle('data/categories.pkl')

# %%
"""
each pages has a list of the names of the categories wich are linked to
"""
cat = open("wiki-topcats-categories.txt", "r")
cat_per_pages = {}
for i in tqdm(cat):
    category = i.split()[0][9:-1]
    page_in_cat = list(map(int, i.split()[1:]))
    
    for x in page_in_cat:
        if x not in cat_per_pages:
            a= []
            a.append(category)
            cat_per_pages[x]=a
        else: 
            aux = list(cat_per_pages[x])
            aux.append(category)
            cat_per_pages[x]= aux
# Out:
# 17364it [00:17, 974.94it/s]

# %%
cat_per_pages
# Out:
# {301: ['Buprestoidea'],
#  302: ['Buprestoidea'],
#  303: ['Buprestoidea', 'Insect_families'],
#  304: ['Buprestoidea'],
#  305: ['Buprestoidea'],
#  306: ['Buprestoidea'],
#  307: ['Buprestoidea'],
#  308: ['Buprestoidea'],
#  309: ['Buprestoidea'],
#  310: ['Buprestoidea'],
#  311: ['Buprestoidea'],
#  312: ['Buprestoidea'],
#  313: ['Buprestoidea'],
#  314: ['Buprestoidea'],
#  315: ['Buprestoidea'],
#  316: ['Buprestoidea'],
#  317: ['Buprestoidea'],
#  318: ['Buprestoidea'],
#  319: ['Buprestoidea'],
#  320: ['Buprestoidea'],
#  321: ['Buprestoidea'],
#  322: ['Buprestoidea'],
#  323: ['Buprestoidea'],
#  324: ['Buprestoidea'],
#  325: ['Buprestoidea'],
#  326: ['Buprestoidea'],
#  327: ['Buprestoidea'],
#  328: ['Buprestoidea'],
#  329: ['Buprestoidea'],
#  330: ['Buprestoidea'],
#  331: ['Buprestoidea'],
#  332: ['Buprestoidea'],
#  333: ['Buprestoidea'],
#  334: ['Buprestoidea'],
#  335: ['Buprestoidea'],
#  336: ['Buprestoidea'],
#  337: ['Buprestoidea'],
#  338: ['Buprestoidea'],
#  339: ['Buprestoidea'],
#  340: ['Buprestoidea'],
#  341: ['Buprestoidea'],
#  342: ['Buprestoidea'],
#  343: ['Buprestoidea'],
#  344: ['Buprestoidea'],
#  345: ['Buprestoidea'],
#  346: ['Buprestoidea'],
#  347: ['Buprestoidea'],
#  348: ['Buprestoidea'],
#  349: ['Buprestoidea'],
#  350: ['Buprestoidea'],
#  351: ['Buprestoidea'],
#  352: ['Buprestoidea'],
#  353: ['Buprestoidea'],
#  354: ['Buprestoidea'],
#  355: ['Buprestoidea'],
#  356: ['Buprestoidea'],
#  357: ['Buprestoidea'],
#  358: ['Buprestoidea'],
#  359: ['Buprestoidea'],
#  360: ['Buprestoidea'],
#  361: ['Buprestoidea'],
#  362: ['Buprestoidea'],
#  363: ['Buprestoidea'],
#  364: ['Buprestoidea'],
#  365: ['Buprestoidea'],
#  366: ['Buprestoidea'],
#  367: ['Buprestoidea'],
#  368: ['Buprestoidea'],
#  369: ['Buprestoidea'],
#  370: ['Buprestoidea'],
#  371: ['Buprestoidea'],
#  372: ['Buprestoidea'],
#  373: ['Buprestoidea'],
#  374: ['Buprestoidea'],
#  375: ['Buprestoidea'],
#  376: ['Buprestoidea'],
#  377: ['Buprestoidea'],
#  378: ['Buprestoidea'],
#  379: ['Buprestoidea'],
#  380: ['Buprestoidea'],
#  381: ['Buprestoidea'],
#  382: ['Buprestoidea'],
#  383: ['Buprestoidea'],
#  384: ['Buprestoidea'],
#  385: ['Buprestoidea'],
#  386: ['Buprestoidea'],
#  387: ['Buprestoidea'],
#  388: ['Buprestoidea'],
#  389: ['Buprestoidea'],
#  390: ['Buprestoidea'],
#  391: ['Buprestoidea'],
#  392: ['Buprestoidea'],
#  393: ['Buprestoidea'],
#  394: ['Buprestoidea'],
#  395: ['Buprestoidea'],
#  396: ['Buprestoidea'],
#  397: ['Buprestoidea'],
#  398: ['Buprestoidea'],
#  399: ['Buprestoidea'],
#  400: ['Buprestoidea'],
#  401: ['Buprestoidea'],
#  402: ['Buprestoidea'],
#  403: ['Buprestoidea'],
#  404: ['Buprestoidea'],
#  405: ['Buprestoidea'],
#  406: ['Buprestoidea'],
#  407: ['Buprestoidea'],
#  408: ['Buprestoidea'],
#  409: ['Buprestoidea'],
#  410: ['Buprestoidea'],
#  411: ['Buprestoidea'],
#  412: ['Buprestoidea'],
#  413: ['Buprestoidea'],
#  414: ['Buprestoidea'],
#  415: ['Buprestoidea'],
#  416: ['Buprestoidea'],
#  417: ['Buprestoidea'],
#  418: ['Buprestoidea'],
#  419: ['Buprestoidea'],
#  420: ['Buprestoidea'],
#  421: ['Buprestoidea'],
#  422: ['Buprestoidea'],
#  423: ['Buprestoidea'],
#  424: ['Buprestoidea'],
#  425: ['Buprestoidea'],
#  426: ['Buprestoidea'],
#  427: ['Buprestoidea'],
#  428: ['Buprestoidea'],
#  429: ['Buprestoidea'],
#  430: ['Buprestoidea'],
#  431: ['Buprestoidea'],
#  432: ['Buprestoidea'],
#  433: ['Buprestoidea'],
#  434: ['Buprestoidea'],
#  435: ['Buprestoidea'],
#  436: ['Buprestoidea'],
#  437: ['Buprestoidea'],
#  438: ['Buprestoidea'],
#  439: ['Buprestoidea'],
#  440: ['Buprestoidea'],
#  441: ['Buprestoidea'],
#  442: ['Buprestoidea'],
#  443: ['Buprestoidea'],
#  444: ['Buprestoidea'],
#  445: ['Buprestoidea'],
#  446: ['Buprestoidea'],
#  447: ['Buprestoidea'],
#  448: ['Buprestoidea'],
#  449: ['Buprestoidea'],
#  450: ['Buprestoidea'],
#  451: ['Buprestoidea'],
#  452: ['Buprestoidea'],
#  453: ['Buprestoidea'],
#  454: ['Buprestoidea'],
#  455: ['Buprestoidea'],
#  456: ['Buprestoidea'],
#  457: ['Buprestoidea'],
#  458: ['Buprestoidea'],
#  459: ['Buprestoidea'],
#  460: ['Buprestoidea'],
#  461: ['Buprestoidea'],
#  462: ['Buprestoidea'],
#  463: ['Buprestoidea'],
#  464: ['Buprestoidea'],
#  465: ['Buprestoidea'],
#  466: ['Buprestoidea'],
#  467: ['Buprestoidea'],
#  468: ['Buprestoidea'],
#  469: ['Buprestoidea'],
#  470: ['Buprestoidea'],
#  471: ['Buprestoidea'],
#  472: ['Buprestoidea'],
#  473: ['Buprestoidea'],
#  474: ['Buprestoidea'],
#  475: ['Buprestoidea'],
#  476: ['Buprestoidea'],
#  477: ['Buprestoidea'],
#  478: ['Buprestoidea'],
#  479: ['Buprestoidea'],
#  480: ['Buprestoidea'],
#  481: ['Buprestoidea'],
#  482: ['Buprestoidea'],
#  483: ['Buprestoidea'],
#  484: ['Buprestoidea'],
#  485: ['Buprestoidea'],
#  486: ['Buprestoidea'],
#  487: ['Buprestoidea'],
#  488: ['Buprestoidea'],
#  489: ['Buprestoidea'],
#  490: ['Buprestoidea'],
#  491: ['Buprestoidea'],
#  492: ['Buprestoidea'],
#  493: ['Buprestoidea'],
#  494: ['Buprestoidea'],
#  495: ['Buprestoidea'],
#  496: ['Buprestoidea'],
#  497: ['Buprestoidea'],
#  498: ['Buprestoidea'],
#  499: ['Buprestoidea'],
#  500: ['Buprestoidea'],
#  501: ['Buprestoidea'],
#  502: ['Buprestoidea'],
#  503: ['Buprestoidea'],
#  504: ['Buprestoidea'],
#  505: ['Buprestoidea'],
#  506: ['Buprestoidea'],
#  507: ['Buprestoidea'],
#  508: ['Buprestoidea'],
#  509: ['Buprestoidea'],
#  510: ['Buprestoidea'],
#  511: ['Buprestoidea'],
#  512: ['Buprestoidea'],
#  513: ['Buprestoidea'],
#  514: ['Buprestoidea'],
#  515: ['Buprestoidea'],
#  516: ['Buprestoidea'],
#  517: ['Buprestoidea'],
#  518: ['Buprestoidea'],
#  519: ['Buprestoidea'],
#  520: ['Buprestoidea'],
#  521: ['Buprestoidea'],
#  522: ['Buprestoidea'],
#  523: ['Buprestoidea'],
#  524: ['Buprestoidea'],
#  525: ['Buprestoidea'],
#  526: ['Buprestoidea'],
#  527: ['Buprestoidea'],
#  528: ['Buprestoidea'],
#  529: ['Buprestoidea'],
#  530: ['Buprestoidea'],
#  531: ['Buprestoidea'],
#  532: ['Buprestoidea'],
#  533: ['Buprestoidea'],
#  534: ['Buprestoidea'],
#  535: ['Buprestoidea'],
#  536: ['Buprestoidea'],
#  537: ['Buprestoidea'],
#  538: ['Buprestoidea'],
#  539: ['Buprestoidea'],
#  540: ['Buprestoidea'],
#  541: ['Buprestoidea'],
#  542: ['Buprestoidea'],
#  543: ['Buprestoidea'],
#  544: ['Buprestoidea'],
#  545: ['Buprestoidea'],
#  546: ['Buprestoidea'],
#  547: ['Buprestoidea'],
#  548: ['Buprestoidea'],
#  549: ['Buprestoidea'],
#  550: ['Buprestoidea'],
#  551: ['Buprestoidea'],
#  552: ['Buprestoidea'],
#  553: ['Buprestoidea'],
#  554: ['Buprestoidea'],
#  555: ['Buprestoidea'],
#  556: ['Buprestoidea'],
#  557: ['Buprestoidea'],
#  558: ['Buprestoidea'],
#  559: ['Buprestoidea'],
#  560: ['Buprestoidea'],
#  561: ['Buprestoidea'],
#  562: ['Buprestoidea'],
#  563: ['Buprestoidea'],
#  564: ['Buprestoidea'],
#  565: ['Buprestoidea'],
#  566: ['Buprestoidea'],
#  567: ['Buprestoidea'],
#  568: ['Buprestoidea'],
#  569: ['Buprestoidea'],
#  570: ['Buprestoidea'],
#  571: ['Buprestoidea'],
#  572: ['Buprestoidea'],
#  573: ['Buprestoidea'],
#  574: ['Buprestoidea'],
#  575: ['Buprestoidea'],
#  576: ['Buprestoidea'],
#  577: ['Buprestoidea'],
#  578: ['Buprestoidea'],
#  579: ['Buprestoidea'],
#  580: ['Buprestoidea'],
#  581: ['Buprestoidea'],
#  582: ['Buprestoidea'],
#  583: ['Buprestoidea'],
#  584: ['Buprestoidea'],
#  585: ['Buprestoidea'],
#  586: ['Buprestoidea'],
#  587: ['Buprestoidea'],
#  588: ['Buprestoidea'],
#  589: ['Buprestoidea'],
#  590: ['Buprestoidea'],
#  591: ['Buprestoidea'],
#  592: ['Buprestoidea'],
#  593: ['Buprestoidea'],
#  594: ['Buprestoidea'],
#  595: ['Buprestoidea'],
#  596: ['Buprestoidea'],
#  597: ['Buprestoidea'],
#  598: ['Buprestoidea'],
#  599: ['Buprestoidea'],
#  600: ['Buprestoidea'],
#  601: ['Buprestoidea'],
#  602: ['Buprestoidea'],
#  603: ['Buprestoidea'],
#  604: ['Buprestoidea'],
#  605: ['Buprestoidea'],
#  606: ['Buprestoidea'],
#  607: ['Buprestoidea'],
#  608: ['Buprestoidea'],
#  609: ['Buprestoidea'],
#  610: ['Buprestoidea'],
#  611: ['Buprestoidea'],
#  612: ['Buprestoidea'],
#  613: ['Buprestoidea'],
#  614: ['Buprestoidea'],
#  615: ['Buprestoidea'],
#  616: ['Buprestoidea'],
#  617: ['Buprestoidea'],
#  618: ['Buprestoidea'],
#  619: ['Buprestoidea'],
#  620: ['Buprestoidea'],
#  621: ['Buprestoidea'],
#  622: ['Buprestoidea'],
#  623: ['Buprestoidea'],
#  624: ['Buprestoidea'],
#  625: ['Buprestoidea'],
#  626: ['Buprestoidea'],
#  627: ['Buprestoidea'],
#  628: ['Buprestoidea'],
#  629: ['Buprestoidea'],
#  630: ['Buprestoidea'],
#  631: ['Buprestoidea'],
#  632: ['Buprestoidea'],
#  633: ['Buprestoidea'],
#  634: ['Buprestoidea'],
#  635: ['Buprestoidea'],
#  636: ['Buprestoidea'],
#  637: ['Buprestoidea'],
#  638: ['Buprestoidea'],
#  639: ['Buprestoidea'],
#  640: ['Buprestoidea'],
#  641: ['Buprestoidea'],
#  642: ['Buprestoidea'],
#  643: ['Buprestoidea'],
#  644: ['Buprestoidea'],
#  645: ['Buprestoidea'],
#  646: ['Buprestoidea'],
#  647: ['Buprestoidea'],
#  648: ['Buprestoidea'],
#  649: ['Buprestoidea'],
#  650: ['Buprestoidea'],
#  651: ['Buprestoidea'],
#  652: ['Buprestoidea'],
#  653: ['Buprestoidea'],
#  654: ['Buprestoidea'],
#  655: ['Buprestoidea'],
#  656: ['Buprestoidea'],
#  657: ['Buprestoidea'],
#  658: ['Buprestoidea'],
#  659: ['Buprestoidea'],
#  660: ['Buprestoidea'],
#  661: ['Buprestoidea'],
#  662: ['Buprestoidea'],
#  663: ['Buprestoidea'],
#  664: ['Buprestoidea'],
#  665: ['Buprestoidea'],
#  666: ['Buprestoidea'],
#  667: ['Buprestoidea'],
#  668: ['Buprestoidea'],
#  669: ['Buprestoidea'],
#  670: ['Buprestoidea'],
#  671: ['Buprestoidea'],
#  672: ['Buprestoidea'],
#  673: ['Buprestoidea'],
#  674: ['Buprestoidea'],
#  675: ['Buprestoidea'],
#  676: ['Buprestoidea'],
#  677: ['Buprestoidea'],
#  678: ['Buprestoidea'],
#  679: ['Buprestoidea'],
#  680: ['Buprestoidea'],
#  681: ['Buprestoidea'],
#  682: ['Buprestoidea'],
#  683: ['Buprestoidea'],
#  684: ['Buprestoidea'],
#  685: ['Buprestoidea'],
#  686: ['Buprestoidea'],
#  687: ['Buprestoidea'],
#  688: ['Buprestoidea'],
#  689: ['Buprestoidea'],
#  690: ['Buprestoidea'],
#  691: ['Buprestoidea'],
#  692: ['Buprestoidea'],
#  693: ['Buprestoidea'],
#  694: ['Buprestoidea'],
#  695: ['Buprestoidea'],
#  696: ['Buprestoidea'],
#  697: ['Buprestoidea'],
#  698: ['Buprestoidea'],
#  699: ['Buprestoidea'],
#  700: ['Buprestoidea'],
#  701: ['Buprestoidea'],
#  702: ['Buprestoidea'],
#  703: ['Buprestoidea'],
#  704: ['Buprestoidea'],
#  705: ['Buprestoidea'],
#  706: ['Buprestoidea'],
#  707: ['Buprestoidea'],
#  708: ['Buprestoidea'],
#  709: ['Buprestoidea'],
#  710: ['Buprestoidea'],
#  711: ['Buprestoidea'],
#  712: ['Buprestoidea'],
#  713: ['Buprestoidea'],
#  714: ['Buprestoidea'],
#  715: ['Buprestoidea'],
#  716: ['Buprestoidea'],
#  717: ['Buprestoidea'],
#  718: ['Buprestoidea'],
#  719: ['Buprestoidea'],
#  720: ['Buprestoidea'],
#  721: ['Buprestoidea'],
#  722: ['Buprestoidea'],
#  723: ['Buprestoidea'],
#  724: ['Buprestoidea'],
#  725: ['Buprestoidea'],
#  726: ['Buprestoidea'],
#  727: ['Buprestoidea'],
#  728: ['Buprestoidea'],
#  729: ['Buprestoidea'],
#  730: ['Buprestoidea'],
#  731: ['Buprestoidea'],
#  732: ['Buprestoidea'],
#  733: ['Buprestoidea'],
#  734: ['Buprestoidea'],
#  735: ['Buprestoidea'],
#  736: ['Buprestoidea'],
#  737: ['Buprestoidea'],
#  738: ['Buprestoidea'],
#  739: ['Buprestoidea'],
#  740: ['Buprestoidea'],
#  741: ['Buprestoidea'],
#  742: ['Buprestoidea'],
#  743: ['Buprestoidea'],
#  744: ['Buprestoidea'],
#  745: ['Buprestoidea'],
#  746: ['Buprestoidea'],
#  747: ['Buprestoidea'],
#  748: ['Buprestoidea'],
#  749: ['Buprestoidea'],
#  750: ['Buprestoidea'],
#  751: ['Buprestoidea'],
#  752: ['Buprestoidea'],
#  753: ['Buprestoidea'],
#  754: ['Buprestoidea'],
#  755: ['Buprestoidea'],
#  756: ['Buprestoidea'],
#  757: ['Buprestoidea'],
#  758: ['Buprestoidea'],
#  759: ['Buprestoidea'],
#  760: ['Buprestoidea'],
#  761: ['Buprestoidea'],
#  762: ['Buprestoidea'],
#  763: ['Buprestoidea'],
#  764: ['Buprestoidea'],
#  765: ['Buprestoidea'],
#  766: ['Buprestoidea'],
#  767: ['Buprestoidea'],
#  768: ['Buprestoidea'],
#  769: ['Buprestoidea'],
#  770: ['Buprestoidea'],
#  771: ['Buprestoidea'],
#  772: ['Buprestoidea'],
#  773: ['Buprestoidea'],
#  774: ['Buprestoidea'],
#  775: ['Buprestoidea'],
#  776: ['Buprestoidea'],
#  777: ['Buprestoidea'],
#  778: ['Buprestoidea'],
#  779: ['Buprestoidea'],
#  780: ['Buprestoidea'],
#  781: ['Buprestoidea'],
#  782: ['Buprestoidea'],
#  783: ['Buprestoidea'],
#  784: ['Buprestoidea'],
#  785: ['Buprestoidea'],
#  786: ['Buprestoidea'],
#  787: ['Buprestoidea'],
#  788: ['Buprestoidea'],
#  789: ['Buprestoidea'],
#  790: ['Buprestoidea'],
#  791: ['Buprestoidea'],
#  792: ['Buprestoidea'],
#  793: ['Buprestoidea'],
#  794: ['Buprestoidea'],
#  795: ['Buprestoidea'],
#  796: ['Buprestoidea'],
#  797: ['Buprestoidea'],
#  798: ['Buprestoidea'],
#  799: ['Buprestoidea'],
#  800: ['Buprestoidea'],
#  801: ['Buprestoidea'],
#  802: ['Buprestoidea'],
#  803: ['Buprestoidea'],
#  804: ['Buprestoidea'],
#  805: ['Buprestoidea'],
#  806: ['Buprestoidea'],
#  807: ['Buprestoidea'],
#  808: ['Buprestoidea'],
#  809: ['Buprestoidea'],
#  810: ['Buprestoidea'],
#  811: ['Buprestoidea'],
#  812: ['Buprestoidea'],
#  813: ['Buprestoidea'],
#  814: ['Buprestoidea'],
#  815: ['Buprestoidea'],
#  816: ['Buprestoidea'],
#  817: ['Buprestoidea'],
#  818: ['Buprestoidea'],
#  819: ['Buprestoidea'],
#  820: ['Buprestoidea'],
#  821: ['Buprestoidea'],
#  822: ['Buprestoidea'],
#  823: ['Buprestoidea'],
#  824: ['Buprestoidea'],
#  825: ['Buprestoidea'],
#  826: ['Buprestoidea'],
#  827: ['Buprestoidea'],
#  828: ['Buprestoidea'],
#  829: ['Buprestoidea'],
#  830: ['Buprestoidea'],
#  831: ['Buprestoidea'],
#  832: ['Buprestoidea'],
#  833: ['Buprestoidea'],
#  834: ['Buprestoidea'],
#  835: ['Buprestoidea'],
#  836: ['Buprestoidea'],
#  837: ['Buprestoidea'],
#  838: ['Buprestoidea'],
#  839: ['Buprestoidea'],
#  840: ['Buprestoidea'],
#  841: ['Buprestoidea'],
#  842: ['Buprestoidea'],
#  1791374: ['Buprestoidea'],
#  1056: ['People_from_Worcester',
#   'English_engineers',
#   'Year_of_birth_missing',
#   "Alumni_of_St_John's_College,_Cambridge"],
#  1057: ['People_from_Worcester',
#   'English_Anglican_priests',
#   'Alumni_of_New_College,_Oxford'],
#  1058: ['People_from_Worcester',
#   'Living_people',
#   'Alumni_of_Loughborough_University',
#   'British_writers',
#   'British_television_presenters',
#   'British_radio_personalities'],
#  1059: ['People_from_Worcester',
#   'Living_people',
#   "English_children's_writers"],
#  1060: ['People_from_Worcester', 'Alumni_of_Hertford_College,_Oxford'],
#  60971: ['People_from_Worcester',
#   'People_of_the_Tudor_period',
#   '16th-century_English_people'],
#  76515: ['People_from_Worcester',
#   'Cheltenham_Town_F.C._players',
#   'English_footballers',
#   'The_Football_League_players',
#   'Shrewsbury_Town_F.C._players',
#   'Association_football_defenders',
#   'Living_people'],
#  76871: ['People_from_Worcester',
#   'English_footballers',
#   'English_football_managers',
#   'Aston_Villa_F.C._players',
#   'Yeovil_Town_F.C._players',
#   'Southampton_F.C._players'],
#  78094: ['People_from_Worcester',
#   'Worcester_City_F.C._players',
#   'Cardiff_City_F.C._players',
#   'English_footballers',
#   'The_Football_League_players',
#   'Living_people'],
#  79069: ['People_from_Worcester',
#   'Nuneaton_Town_F.C._players',
#   'Worcester_City_F.C._players',
#   'Huddersfield_Town_F.C._players',
#   'Swindon_Town_F.C._players',
#   'Sheffield_United_F.C._players',
#   'English_footballers',
#   'The_Football_League_players',
#   'Association_football_midfielders',
#   'Rushden_&_Diamonds_F.C._players',
#   'Bury_F.C._players',
#   'Living_people'],
#  79139: ['People_from_Worcester',
#   'Worcester_City_F.C._players',
#   'Port_Vale_F.C._players',
#   'Wolverhampton_Wanderers_F.C._players',
#   'English_footballers',
#   'The_Football_League_players',
#   'Association_football_forwards',
#   'Association_football_midfielders',
#   'Living_people'],
#  79143: ['People_from_Worcester',
#   'Nuneaton_Town_F.C._players',
#   'Kidderminster_Harriers_F.C._players',
#   'English_footballers',
#   'Association_football_midfielders',
#   'Burton_Albion_F.C._players',
#   'Living_people'],
#  80237: ['People_from_Worcester',
#   'England_under-21_international_footballers',
#   'English_footballers',
#   'The_Football_League_players',
#   'England_youth_international_footballers',
#   'Aston_Villa_F.C._players',
#   'Lincoln_City_F.C._players',
#   'Association_football_defenders',
#   'Living_people'],
#  84108: ['People_from_Worcester',
#   'Chesterfield_F.C._players',
#   'Wolverhampton_Wanderers_F.C._players',
#   'English_footballers',
#   'The_Football_League_players',
#   'Northampton_Town_F.C._players',
#   'Peterborough_United_F.C._players',
#   'Association_football_defenders',
#   'Living_people'],
#  84354: ['People_from_Worcester',
#   'Gillingham_F.C._players',
#   'Association_football_utility_players',
#   'English_footballers',
#   'The_Football_League_players',
#   'Aston_Villa_F.C._players',
#   'Stockport_County_F.C._players',
#   'Northampton_Town_F.C._players',
#   'Cambridge_United_F.C._players',
#   'Association_football_defenders',
#   'Living_people'],
#  84740: ['People_from_Worcester', 'English_football_referees'],
#  85268: ['People_from_Worcester',
#   'Portsmouth_F.C._players',
#   'English_footballers',
#   'The_Football_League_players',
#   'Association_football_forwards',
#   'Crystal_Palace_F.C._players',
#   'Exeter_City_F.C._players',
#   'Southampton_F.C._players',
#   'English_cricketers',
#   'Hampshire_cricketers',
#   'Sportspeople_of_multiple_sports'],
#  85767: ['People_from_Worcester',
#   'Stoke_City_F.C._players',
#   'Hull_City_A.F.C._players',
#   'English_footballers',
#   'The_Football_League_players',
#   'Nottingham_Forest_F.C._players',
#   'Aston_Villa_F.C._players',
#   'Bradford_City_A.F.C._players',
#   'Burnley_F.C._players',
#   'Shrewsbury_Town_F.C._players',
#   'Rochdale_A.F.C._players',
#   'Partick_Thistle_F.C._players',
#   'Living_people'],
#  89734: ['People_from_Worcester',
#   'Portsmouth_F.C._players',
#   'England_under-21_international_footballers',
#   'English_footballers',
#   'Living_people'],
#  90171: ['People_from_Worcester',
#   'Bath_City_F.C._players',
#   'Hednesford_Town_F.C._players',
#   'Cheltenham_Town_F.C._players',
#   'English_footballers',
#   'The_Football_League_players',
#   'Association_football_forwards',
#   'Living_people',
#   'Chelmsford_City_F.C._players'],
#  95330: ['People_from_Worcester', 'English_civil_engineers'],
#  158412: ['People_from_Worcester'],
#  166087: ['People_from_Worcester',
#   'Benedictines',
#   '16th-century_Roman_Catholics',
#   'English_Roman_Catholics',
#   'People_of_the_Stuart_period',
#   '17th-century_English_people',
#   'People_of_the_Tudor_period',
#   '16th-century_English_people'],
#  194583: ['People_from_Worcester',
#   'Living_people',
#   "Norwegian_children's_writers",
#   'People_from_Brum'],
#  196217: ['People_from_Worcester',
#   '11th-century_rulers_in_Europe',
#   'Year_of_birth_unknown',
#   '10th-century_rulers_in_Europe',
#   'Regents'],
#  216650: ['People_from_Worcester',
#   'Living_people',
#   'English_classical_organists',
#   'Cathedral_organists',
#   'Year_of_birth_missing_(living_people)',
#   'Academics_of_the_University_of_East_Anglia',
#   'English_conductors_(music)',
#   "Alumni_of_St_John's_College,_Cambridge"],
#  216770: ['People_from_Worcester',
#   'English_classical_organists',
#   'Cathedral_organists',
#   "Alumni_of_The_Queen's_College,_Oxford",
#   'Commanders_of_the_Order_of_the_British_Empire',
#   '20th-century_classical_composers',
#   'English_composers',
#   'Academics_of_the_Royal_College_of_Music'],
#  348758: ['People_from_Worcester', 'English_Christian_ministers'],
#  350247: ['People_from_Worcester',
#   'English_medical_doctors',
#   'Fellows_of_New_College,_Oxford',
#   'Alumni_of_New_College,_Oxford',
#   'Fellows_of_the_Royal_Society'],
#  350259: ['People_from_Worcester',
#   'English_medical_doctors',
#   '19th-century_writers',
#   '19th-century_English_people',
#   '18th-century_English_people',
#   '18th-century_writers'],
#  350608: ['People_from_Worcester',
#   'Alumni_of_Balliol_College,_Oxford',
#   'Fellows_of_University_College,_Oxford',
#   'Physical_chemists',
#   'Fellows_of_the_Royal_Society',
#   'English_chemists'],
#  372883: ['People_from_Worcester',
#   'People_from_Ottawa',
#   'People_from_Kingston,_Ontario',
#   'Canadian_painters',
#   'Landscape_artists',
#   'Royal_Engineers_officers'],
#  377480: ['People_from_Worcester',
#   'Burials_at_Green-Wood_Cemetery',
#   '19th-century_baseball_players',
#   'Major_League_Baseball_third_basemen'],
#  437692: ['People_from_Worcester',
#   'Presidents_of_the_Institution_of_Civil_Engineers',
#   'British_civil_engineers',
#   'Old_Cheltonians',
#   "Alumni_of_King's_College,_Cambridge"],
#  449761: ['People_from_Worcester',
#   'Living_people',
#   'Fellows_of_the_Royal_Historical_Society',
#   'Alumni_of_Hertford_College,_Oxford',
#   'Fellows_of_the_Royal_Society_of_Literature'],
#  449809: ['People_from_Worcester',
#   '16th-century_Roman_Catholics',
#   'English_Roman_Catholics',
#   'People_of_the_Tudor_period',
#   '16th-century_English_people',
#   'English_religious_writers'],
#  454664: ['People_from_Worcester',
#   'Recipients_of_the_Royal_Gold_Medal',
#   'English_architects'],
#  494420: ['People_from_Worcester',
#   'Living_people',
#   'Field_hockey_players_at_the_2008_Summer_Olympics',
#   'English_field_hockey_players',
#   'Olympic_field_hockey_players_of_Great_Britain',
#   'Commonwealth_Games_silver_medallists_for_England'],
#  499532: ['People_from_Worcester', 'Living_people'],
#  527094: ['People_from_Worcester',
#   'Living_people',
#   'Members_of_the_Scottish_Parliament_20032007'],
#  537220: ['People_from_Worcester',
#   'Alumni_of_Worcester_College,_Oxford',
#   'UK_MPs_18851886',
#   'UK_MPs_18861892',
#   'UK_MPs_18801885',
#   'UK_MPs_18741880',
#   'UK_MPs_18651868',
#   'UK_MPs_18681874',
#   'UK_MPs_18571859',
#   'UK_MPs_18591865',
#   'UK_MPs_18521857',
#   'Members_of_the_United_Kingdom_Parliament_for_English_constituencies',
#   'Liberal_Party_(UK)_MPs',
#   'Baronets_in_the_Baronetage_of_Great_Britain'],
#  538870: ['People_from_Worcester',
#   'Living_people',
#   'UK_MPs_20012005',
#   'UK_MPs_19972001',
#   'UK_MPs_20052010',
#   'Labour_Party_(UK)_MPs',
#   'Members_of_the_United_Kingdom_Parliament_for_English_constituencies'],
#  540020: ['People_from_Worcester',
#   'Living_people',
#   'UK_MPs_19921997',
#   'UK_MPs_20012005',
#   'UK_MPs_19972001',
#   'UK_MPs_20052010',
#   'UK_MPs_2010',
#   'Members_of_the_United_Kingdom_Parliament_for_English_constituencies',
#   'Conservative_Party_(UK)_MPs',
#   'Alumni_of_Corpus_Christi_College,_Cambridge'],
#  541169: ['People_from_Worcester',
#   'Members_of_the_United_Kingdom_Parliament_for_English_constituencies',
#   'Liberal_Party_(UK)_MPs',
#   'UK_MPs_19221923'],
#  544700: ['People_from_Worcester',
#   'English_medical_doctors',
#   'Date_of_birth_missing',
#   'Date_of_death_missing'],
#  544701: ['People_from_Worcester',
#   'Royal_Navy_admirals',
#   'Knights_Commander_of_the_Order_of_the_Bath'],
#  544738: ['People_from_Worcester'],
#  544888: ['People_from_Worcester'],
#  546749: ['People_from_Worcester'],
#  654238: ['People_from_Worcester',
#   'English_painters',
#   'English_artists',
#   'Alumni_of_the_Royal_College_of_Art',
#   'Contemporary_artists',
#   'Modern_artists'],
#  669757: ['People_from_Worcester',
#   'Living_people',
#   'Worcestershire_cricketers',
#   'Gloucestershire_cricketers',
#   'English_cricketers',
#   'Minor_Counties_cricketers'],
#  721089: ['People_from_Worcester',
#   'Royal_Naval_Air_Service_aviators',
#   'British_World_War_I_flying_aces',
#   'Recipients_of_the_Distinguished_Service_Cross_(United_Kingdom)',
#   'Date_of_death_missing',
#   'Place_of_death_missing'],
#  721539: ['People_from_Worcester',
#   "Academics_of_King's_College_London",
#   'Liberal_Democrat_life_peers',
#   'Alumni_of_Magdalene_College,_Cambridge',
#   'Royal_Air_Force_air_marshals',
#   'Fellows_of_the_Royal_Aeronautical_Society',
#   "Chevaliers_of_the_Lgion_d'honneur",
#   'Cancer_deaths_in_England',
#   'Knights_Commander_of_the_Order_of_the_Bath'],
#  791902: ['People_from_Worcester',
#   'English_watercolourists',
#   'English_painters',
#   'English_illustrators'],
#  799357: ['People_from_Worcester',
#   'English_naturalists',
#   'English_botanists',
#   'Alumni_of_Magdalen_College,_Oxford',
#   '19th-century_English_people'],
#  826926: ['People_from_Worcester',
#   'Living_people',
#   'Old_Wykehamists',
#   'Alumni_of_the_University_of_Cambridge',
#   'English_journalists',
#   'English_novelists',
#   'Fellows_of_the_Royal_Society_of_Literature'],
#  827472: ['People_from_Worcester',
#   'Living_people',
#   'English_women_writers',
#   'English_short_story_writers',
#   'English_novelists'],
#  827479: ['People_from_Worcester',
#   'Burials_at_Highgate_Cemetery',
#   'English_women_writers',
#   'English_novelists',
#   'Women_novelists'],
#  830268: ['People_from_Worcester', "Christ's_Hospital_Old_Blues"],
#  883273: ['People_from_Worcester',
#   'Worcester_City_F.C._players',
#   'English_footballers',
#   'Association_football_goalkeepers',
#   'Living_people'],
#  919797: ['People_from_Worcester',
#   'English_businesspeople',
#   'Members_of_the_Order_of_the_Companions_of_Honour',
#   'Viscounts_in_the_Peerage_of_the_United_Kingdom',
#   'English_philanthropists',
#   'Automotive_pioneers',
#   'Fellows_of_the_Royal_Society',
#   'Founders_of_English_schools_and_colleges',
#   'Knights_Grand_Cross_of_the_Order_of_the_British_Empire'],
#  971629: ['People_from_Worcester',
#   'Living_people',
#   'Alumni_of_the_Slade_School_of_Art',
#   'English_artists',
#   'Conceptual_artists'],
#  979026: ['People_from_Worcester',
#   'Royal_Academicians',
#   'English_painters',
#   'Landscape_artists'],
#  995033: ['People_from_Worcester'],
#  998609: ['People_from_Worcester', 'English_painters'],
#  1011834: ['People_from_Worcester',
#   'Manchester_United_F.C._players',
#   'English_footballers',
#   'Track_cyclists',
#   'Olympic_medalists_in_cycling',
#   'Olympic_cyclists_of_Great_Britain',
#   'English_cyclists',
#   'Olympic_gold_medalists_for_Great_Britain'],
#  1033464: ['People_from_Worcester', 'Living_people', 'English_actors'],
#  1043638: ['People_from_Worcester',
#   'English_television_actors',
#   'English_stage_actors',
#   'English_film_actors'],
#  1043983: ['People_from_Worcester',
#   'English_television_actors',
#   'English_film_actors',
#   'Deaths_from_lung_cancer',
#   'Old_Amplefordians'],
#  1047370: ['People_from_Worcester',
#   'Living_people',
#   'English_actors',
#   'Olivier_Award_winners'],
#  1112567: ['People_from_Worcester', 'Living_people', 'British_Jews'],
#  1142375: ['People_from_Worcester',
#   'Fellows_of_All_Souls_College,_Oxford',
#   'Tudor_bishops',
#   '16th-century_English_people',
#   'Bishops_of_Worcester'],
#  1143260: ['People_from_Worcester',
#   'English_architects',
#   'Chancellors_of_the_Duchy_of_Lancaster',
#   '15th-century_English_people',
#   'Knights_of_the_Garter',
#   'People_of_the_Tudor_period',
#   '16th-century_English_people'],
#  1170545: ['People_from_Worcester',
#   'English_merchants',
#   'People_of_the_Tudor_period',
#   '16th-century_English_people',
#   'Members_of_the_pre-1707_Parliament_of_England',
#   'Date_of_death_missing'],
#  1178634: ['People_from_Worcester',
#   'Living_people',
#   'English_rock_guitarists',
#   'English_songwriters'],
#  1194242: ['People_from_Worcester',
#   'Living_people',
#   'Alumni_of_the_University_of_Oxford',
#   'English_journalists',
#   'English_poets',
#   'English_writers',
#   'The_Guardian_journalists'],
#  1260349: ['People_from_Worcester',
#   'Living_people',
#   'Alumni_of_Lincoln_College,_Oxford',
#   'English_academics',
#   'English_short_story_writers',
#   'English_literary_critics'],
#  1284729: ['People_from_Worcester',
#   'English_aviators',
#   'English_actors',
#   'Female_aviators',
#   'Officers_of_the_Order_of_the_British_Empire'],
#  1287891: ['People_from_Worcester',
#   'Living_people',
#   'British_radio_personalities'],
#  1287952: ['People_from_Worcester',
#   'Living_people',
#   'British_radio_personalities',
#   'British_radio_DJs'],
#  1342966: ['People_from_Worcester'],
#  1343202: ['People_from_Worcester'],
#  1385068: ['People_from_Worcester',
#   'Royal_Academicians',
#   'English_sculptors',
#   'Knights_Commander_of_the_Order_of_the_Bath'],
#  1390440: ['People_from_Worcester',
#   'Christian_hymnwriters',
#   'English_Anglican_priests',
#   "Alumni_of_The_Queen's_College,_Oxford"],
#  1445619: ['People_from_Worcester', 'MCC_cricketers', 'English_cricketers'],
#  1470844: ['People_from_Worcester',
#   'Barons_in_the_Peerage_of_Ireland',
#   '16th-century_Irish_people',
#   'People_of_Elizabethan_Ireland',
#   '17th-century_Irish_people',
#   '17th-century_English_people',
#   'People_of_the_Tudor_period',
#   '16th-century_English_people'],
#  1472916: ['People_from_Worcester',
#   'British_World_War_I_recipients_of_the_Victoria_Cross',
#   'British_military_personnel_killed_in_World_War_I',
#   'British_Army_personnel_of_World_War_I'],
#  1499171: ['People_from_Worcester',
#   'People_of_the_Edwardian_era',
#   'Academics_of_the_University_of_Birmingham',
#   'Baronets_in_the_Baronetage_of_the_United_Kingdom',
#   'Members_of_the_Order_of_Merit',
#   'English_Roman_Catholics',
#   'Knights_Grand_Cross_of_the_Royal_Victorian_Order',
#   'Composers_for_pipe_organ',
#   '20th-century_classical_composers',
#   'English_conductors_(music)',
#   'English_composers',
#   'Ballet_composers',
#   'Romantic_composers'],
#  1506216: ['People_from_Worcester', 'English_composers'],
#  1516445: ['People_from_Worcester',
#   'English_educators',
#   'Alumni_of_Brasenose_College,_Oxford',
#   'Alumni_of_Balliol_College,_Oxford',
#   '17th-century_English_people',
#   'People_of_the_Tudor_period',
#   '16th-century_English_people'],
#  1525160: ['People_from_Worcester',
#   'Living_people',
#   'English_rugby_union_players'],
#  1525827: ['People_from_Worcester',
#   'Living_people',
#   'English_rugby_union_players',
#   'Rugby_union_flankers'],
#  1527616: ['People_from_Worcester',
#   'Living_people',
#   'Rugby_union_number_eights',
#   'England_international_rugby_union_players',
#   'English_rugby_union_players',
#   'Gloucester_Rugby_players'],
#  1565695: ['People_from_Worcester',
#   'Living_people',
#   'Olympic_silver_medalists_for_Great_Britain',
#   'Sailors_at_the_2000_Summer_Olympics',
#   'Olympic_medalists_in_sailing'],
#  1568124: ['People_from_Worcester',
#   'Living_people',
#   'Commonwealth_Games_silver_medallists_for_England',
#   'Swimmers_at_the_1992_Summer_Olympics',
#   'Olympic_swimmers_of_Great_Britain',
#   'English_swimmers',
#   'Swimmers_at_the_1996_Summer_Olympics',
#   'Backstroke_swimmers'],
#  1610622: ['People_from_Worcester', 'Edmonton_city_councillors'],
#  1646864: ['People_from_Worcester', 'Locomotive_builders_and_designers'],
#  1653449: ['People_from_Worcester',
#   'English_explorers',
#   'Members_of_the_Privy_Council_of_the_United_Kingdom',
#   'Barons_in_the_Peerage_of_the_United_Kingdom',
#   'People_from_Chennai',
#   'Knights_Grand_Cross_of_the_Order_of_St_Michael_and_St_George',
#   'Explorers_of_Africa',
#   'British_Army_personnel_of_the_Mahdist_War',
#   'Sandhurst_graduates',
#   'Companions_of_the_Order_of_the_Bath',
#   'Companions_of_the_Distinguished_Service_Order',
#   'Old_Rossallians'],
#  1667832: ['People_from_Worcester',
#   'Alumni_of_Wadham_College,_Oxford',
#   'Old_Rugbeians',
#   'National_Historic_Persons_of_Canada',
#   "People_from_St._John's,_Newfoundland_and_Labrador",
#   '19th-century_Anglican_bishops'],
#  1715203: ['People_from_Worcester',
#   'Fellows_of_the_British_Academy',
#   'Knights_Bachelor',
#   'Fellows_of_the_American_Statistical_Association',
#   'Commanders_of_the_Order_of_the_British_Empire',
#   'Alumni_of_Sidney_Sussex_College,_Cambridge',
#   'English_economists',
#   'Academics_of_the_London_School_of_Economics'],
#  1779646: ['People_from_Worcester',
#   '8th-century_Christian_saints',
#   '8th-century_bishops',
#   'Bishops_of_Worcester'],
#  1780461: ['People_from_Worcester'],
#  1781093: ['People_from_Worcester'],
#  971: ['Skin_conditions_resulting_from_physical_factors'],
#  973: ['Skin_conditions_resulting_from_physical_factors'],
#  1166: ['Skin_conditions_resulting_from_physical_factors'],
#  1167: ['Skin_conditions_resulting_from_physical_factors'],
#  1168: ['Skin_conditions_resulting_from_physical_factors'],
#  1169: ['Skin_conditions_resulting_from_physical_factors'],
#  1170: ['Skin_conditions_resulting_from_physical_factors'],
#  1171: ['Skin_conditions_resulting_from_physical_factors'],
#  1172: ['Skin_conditions_resulting_from_physical_factors'],
#  1173: ['Skin_conditions_resulting_from_physical_factors'],
#  1174: ['Skin_conditions_resulting_from_physical_factors'],
#  1175: ['Skin_conditions_resulting_from_physical_factors'],
#  1176: ['Skin_conditions_resulting_from_physical_factors'],
#  1177: ['Skin_conditions_resulting_from_physical_factors'],
#  2810: ['Skin_conditions_resulting_from_physical_factors'],
#  3574: ['Skin_conditions_resulting_from_physical_factors', 'Tort_law'],
#  5230: ['Skin_conditions_resulting_from_physical_factors'],
#  5319: ['Skin_conditions_resulting_from_physical_factors', 'Medical_signs'],
#  6358: ['Skin_conditions_resulting_from_physical_factors'],
#  6970: ['Skin_conditions_resulting_from_physical_factors'],
#  8220: ['Skin_conditions_resulting_from_physical_factors',
#   '2000s_fashion',
#   '1990s_fashion'],
#  8587: ['Skin_conditions_resulting_from_physical_factors',
#   'Medical_emergencies'],
#  9120: ['Skin_conditions_resulting_from_physical_factors'],
#  9201: ['Skin_conditions_resulting_from_physical_factors'],
#  9348: ['Skin_conditions_resulting_from_physical_factors',
#   'Medical_emergencies'],
#  9440: ['Skin_conditions_resulting_from_physical_factors', 'Medical_signs'],
#  9495: ['Skin_conditions_resulting_from_physical_factors',
#   'Medical_emergencies'],
#  9636: ['Skin_conditions_resulting_from_physical_factors'],
#  9642: ['Skin_conditions_resulting_from_physical_factors'],
#  10053: ['Skin_conditions_resulting_from_physical_factors',
#   'Medical_emergencies'],
#  10897: ['Skin_conditions_resulting_from_physical_factors'],
#  11564: ['Skin_conditions_resulting_from_physical_factors'],
#  12184: ['Skin_conditions_resulting_from_physical_factors'],
#  15516: ['Skin_conditions_resulting_from_physical_factors', 'Radioactivity'],
#  40429: ['Skin_conditions_resulting_from_physical_factors'],
#  150415: ['Skin_conditions_resulting_from_physical_factors'],
#  354222: ['Skin_conditions_resulting_from_physical_factors'],
#  354224: ['Skin_conditions_resulting_from_physical_factors', 'Inflammations'],
#  369562: ['Skin_conditions_resulting_from_physical_factors'],
#  428725: ['Skin_conditions_resulting_from_physical_factors', 'Paper'],
#  851858: ['Skin_conditions_resulting_from_physical_factors'],
#  885574: ['Skin_conditions_resulting_from_physical_factors'],
#  1003941: ['Skin_conditions_resulting_from_physical_factors'],
#  1032218: ['Skin_conditions_resulting_from_physical_factors'],
#  1073413: ['Skin_conditions_resulting_from_physical_factors'],
#  1087184: ['Skin_conditions_resulting_from_physical_factors'],
#  1240875: ['Skin_conditions_resulting_from_physical_factors'],
#  1293461: ['Skin_conditions_resulting_from_physical_factors'],
#  1316419: ['Skin_conditions_resulting_from_physical_factors'],
#  1364950: ['Skin_conditions_resulting_from_physical_factors'],
#  1378135: ['Skin_conditions_resulting_from_physical_factors'],
#  1378136: ['Skin_conditions_resulting_from_physical_factors'],
#  1450546: ['Skin_conditions_resulting_from_physical_factors'],
#  1450547: ['Skin_conditions_resulting_from_physical_factors'],
#  1475467: ['Skin_conditions_resulting_from_physical_factors'],
#  1523943: ['Skin_conditions_resulting_from_physical_factors'],
#  1523944: ['Skin_conditions_resulting_from_physical_factors'],
#  1523945: ['Skin_conditions_resulting_from_physical_factors'],
#  1523946: ['Skin_conditions_resulting_from_physical_factors'],
#  1584014: ['Skin_conditions_resulting_from_physical_factors'],
#  1631187: ['Skin_conditions_resulting_from_physical_factors'],
#  1631188: ['Skin_conditions_resulting_from_physical_factors'],
#  1663489: ['Skin_conditions_resulting_from_physical_factors'],
#  1692063: ['Skin_conditions_resulting_from_physical_factors'],
#  1692064: ['Skin_conditions_resulting_from_physical_factors'],
#  1705410: ['Skin_conditions_resulting_from_physical_factors'],
#  1705411: ['Skin_conditions_resulting_from_physical_factors'],
#  1705412: ['Skin_conditions_resulting_from_physical_factors'],
#  1713424: ['Skin_conditions_resulting_from_physical_factors'],
#  1297: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1300: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Musical_groups_established_in_1992'],
#  1311: ['Visual_kei_bands', 'Japanese_musical_groups'],
#  1312: ['Visual_kei_bands', 'Musical_quintets', 'Sony_Music_Japan_artists'],
#  1313: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1314: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1315: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1316: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1319: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1320: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Sony_Music_Japan_artists'],
#  1321: ['Visual_kei_bands'],
#  1322: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1323: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1324: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1325: ['Visual_kei_bands', 'Japanese_rock_music_groups', 'Musical_quartets'],
#  1326: ['Visual_kei_bands', 'Japanese_rock_music_groups', 'Musical_quintets'],
#  1327: ['Visual_kei_bands', 'Japanese_rock_music_groups', 'Musical_quintets'],
#  1328: ['Visual_kei_bands'],
#  1329: ['Visual_kei_bands', 'Japanese_musical_groups'],
#  1330: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1331: ['Visual_kei_bands'],
#  1332: ['Visual_kei_bands', 'Musical_groups_established_in_1992'],
#  1333: ['Visual_kei_bands', 'Musical_quartets'],
#  1334: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1335: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1336: ['Visual_kei_bands', 'Japanese_musical_groups'],
#  1337: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Japanese_musical_groups'],
#  1338: ['Visual_kei_bands', 'Musical_quintets'],
#  1339: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1340: ['Visual_kei_bands'],
#  1341: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Musical_groups_established_in_2004'],
#  1342: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1343: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1345: ['Visual_kei_bands', 'Japanese_rock_music_groups', 'Musical_quintets'],
#  1346: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1348: ['Visual_kei_bands'],
#  1349: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1350: ['Visual_kei_bands'],
#  1351: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Musical_groups_established_in_1992'],
#  1352: ['Visual_kei_bands', 'Japanese_rock_music_groups', 'Avex_Trax_artists'],
#  1353: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1354: ['Visual_kei_bands', 'Musical_quartets'],
#  1356: ['Visual_kei_bands', 'Japanese_rock_music_groups', 'Avex_Trax_artists'],
#  1357: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1358: ['Visual_kei_bands', 'Japanese_rock_music_groups', 'Musical_quartets'],
#  1359: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1361: ['Visual_kei_bands', 'Japanese_rock_music_groups', 'Musical_quartets'],
#  1363: ['Visual_kei_bands', 'Japanese_rock_music_groups', 'Avex_Trax_artists'],
#  1364: ['Visual_kei_bands', 'Gothic_rock_groups', 'Japanese_musical_groups'],
#  1365: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1366: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Japanese_musical_groups'],
#  1367: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Japanese_musical_groups'],
#  1368: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1369: ['Visual_kei_bands'],
#  1371: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1372: ['Visual_kei_bands', 'Musical_quartets', 'Japanese_musical_groups'],
#  1374: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1375: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Japanese_musical_groups'],
#  1376: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1377: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1378: ['Visual_kei_bands', 'Musical_quartets', 'Japanese_musical_groups'],
#  1380: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1383: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1385: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1387: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Sony_Music_Japan_artists'],
#  1390: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Sony_Music_Japan_artists'],
#  1393: ['Visual_kei_bands', 'Japanese_musical_groups'],
#  1395: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1403: ['Visual_kei_bands', 'Japanese_musical_groups', 'Supergroups'],
#  1404: ['Visual_kei_bands',
#   'Musical_quartets',
#   'Musical_groups_established_in_2004',
#   'Japanese_musical_groups'],
#  1410: ['Visual_kei_bands', 'Musical_quartets'],
#  1411: ['Visual_kei_bands'],
#  1418: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1427: ['Visual_kei_bands', 'Japanese_rock_music_groups', 'Musical_trios'],
#  1429: ['Visual_kei_bands', 'Musical_quartets', 'Japanese_musical_groups'],
#  1431: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Japanese_musical_groups'],
#  1435: ['Visual_kei_bands', 'Japanese_musical_groups'],
#  1440: ['Visual_kei_bands', 'Japanese_rock_music_groups', 'Avex_Trax_artists'],
#  1441: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Musical_groups_established_in_1987',
#   'Musical_quartets'],
#  1446: ['Visual_kei_bands',
#   'Musical_quartets',
#   'Musical_groups_established_in_1992',
#   'Art_rock_musical_groups'],
#  1455: ['Visual_kei_bands', 'Japanese_rock_music_groups', 'Musical_quartets'],
#  1461: ['Visual_kei_bands', 'Musical_quintets'],
#  1466: ['Visual_kei_bands',
#   'Japanese_musical_groups',
#   'Electronic_music_duos'],
#  1473: ['Visual_kei_bands', 'Musical_quintets'],
#  1513: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Musical_quintets',
#   'Atlantic_Records_artists',
#   'Sony_Music_Japan_artists',
#   'Glam_metal_musical_groups'],
#  562072: ['Visual_kei_bands', 'Japanese_musical_groups'],
#  604876: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Living_people',
#   'Musical_quartets',
#   'Internet_memes'],
#  604884: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  604888: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Musical_quartets',
#   'Musical_groups_established_in_2004'],
#  635747: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Gothic_rock_groups',
#   'Musical_quintets'],
#  657073: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Musical_quintets',
#   'Sony_Music_Japan_artists'],
#  719336: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  751685: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Musical_quartets'],
#  773402: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  800357: ['Visual_kei_bands',
#   'Musical_quintets',
#   'Japanese_musical_groups',
#   'All-female_bands'],
#  883789: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Avex_Trax_artists'],
#  1002565: ['Visual_kei_bands', 'Japanese_musical_groups'],
#  1230384: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Japanese_musical_groups'],
#  1368113: ['Visual_kei_bands'],
#  1627518: ['Visual_kei_bands', 'Japanese_rock_music_groups'],
#  1747657: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Musical_groups_established_in_2004'],
#  1754961: ['Visual_kei_bands',
#   'Japanese_rock_music_groups',
#   'Avex_Trax_artists',
#   'Musical_quintets'],
#  1763149: ['Visual_kei_bands',
#   'Musical_quartets',
#   'Musical_groups_established_in_1999'],
#  1360: ['Japanese_rock_music_groups', 'Musical_quartets'],
#  1389: ['Japanese_rock_music_groups'],
#  1392: ['Japanese_rock_music_groups', 'Japanese_musical_groups'],
#  1396: ['Japanese_rock_music_groups', 'Sony_Music_Japan_artists'],
#  1397: ['Japanese_rock_music_groups', 'Garage_punk'],
#  1399: ['Japanese_rock_music_groups', 'Musical_groups_established_in_1999'],
#  1400: ['Japanese_rock_music_groups'],
#  1402: ['Japanese_rock_music_groups'],
#  1408: ['Japanese_rock_music_groups', 'All-female_bands'],
#  1409: ['Japanese_rock_music_groups'],
#  1414: ['Japanese_rock_music_groups'],
#  1417: ['Japanese_rock_music_groups', 'Sony_Music_Japan_artists'],
#  1422: ['Japanese_rock_music_groups', 'Sony_Music_Japan_artists'],
#  1424: ['Japanese_rock_music_groups', 'Japanese_musical_groups'],
#  1425: ['Japanese_rock_music_groups', 'Japanese_musical_groups'],
#  1426: ['Japanese_rock_music_groups'],
#  1430: ['Japanese_rock_music_groups'],
#  1434: ['Japanese_rock_music_groups', 'Musical_quartets'],
#  1436: ['Japanese_rock_music_groups', 'Musical_quartets'],
#  1437: ['Japanese_rock_music_groups'],
#  1439: ['Japanese_rock_music_groups'],
#  1469: ['Japanese_rock_music_groups'],
#  1488: ['Japanese_rock_music_groups'],
#  1491: ['Japanese_rock_music_groups', 'Avex_Trax_artists'],
#  1492: ['Japanese_rock_music_groups'],
#  1499: ['Japanese_rock_music_groups'],
#  1500: ['Japanese_rock_music_groups'],
#  1501: ['Japanese_rock_music_groups'],
#  1506: ['Japanese_rock_music_groups'],
#  1509: ['Japanese_rock_music_groups'],
#  140768: ['Japanese_rock_music_groups'],
#  151198: ['Japanese_rock_music_groups', 'Musical_groups_established_in_2004'],
#  153001: ['Japanese_rock_music_groups'],
#  153029: ['Japanese_rock_music_groups'],
#  153031: ['Japanese_rock_music_groups', 'Japanese_musical_groups'],
#  153036: ['Japanese_rock_music_groups'],
#  153504: ['Japanese_rock_music_groups', 'Sony_Music_Japan_artists'],
#  154490: ['Japanese_rock_music_groups', 'Psychedelic_musical_groups'],
#  208880: ['Japanese_rock_music_groups'],
#  310454: ['Japanese_rock_music_groups',
#   'Japanese_musical_groups',
#   'Musical_duos'],
#  395576: ['Japanese_rock_music_groups', 'People_from_Tokyo'],
#  451504: ['Japanese_rock_music_groups', 'Musical_groups_established_in_1992'],
#  522949: ['Japanese_rock_music_groups'],
#  559569: ['Japanese_rock_music_groups'],
#  562292: ['Japanese_rock_music_groups'],
#  564607: ['Japanese_rock_music_groups',
#   'Musical_quintets',
#   'Musical_groups_established_in_1999'],
#  635741: ['Japanese_rock_music_groups'],
#  635742: ['Japanese_rock_music_groups'],
#  651191: ['Japanese_rock_music_groups'],
#  651200: ['Japanese_rock_music_groups'],
#  676478: ['Japanese_rock_music_groups'],
#  689452: ['Japanese_rock_music_groups'],
#  691204: ['Japanese_rock_music_groups'],
#  694134: ['Japanese_rock_music_groups',
#   'Musical_quintets',
#   'Musical_groups_established_in_1986',
#   'Sony_Music_Japan_artists'],
#  694156: ['Japanese_rock_music_groups', 'Avex_Trax_artists'],
#  694844: ['Japanese_rock_music_groups'],
#  705049: ['Japanese_rock_music_groups', 'Musical_trios'],
#  705061: ['Japanese_rock_music_groups',
#   'Musical_quartets',
#   'Sony_Music_Japan_artists'],
#  718774: ['Japanese_rock_music_groups'],
#  724416: ['Japanese_rock_music_groups', 'Sony_Music_Japan_artists'],
#  734210: ['Japanese_rock_music_groups', 'Avex_Trax_artists', 'Musical_trios'],
#  739279: ['Japanese_rock_music_groups', 'Japanese_musical_groups'],
#  741099: ['Japanese_rock_music_groups'],
#  742287: ['Japanese_rock_music_groups'],
#  749516: ['Japanese_rock_music_groups', 'Garage_punk'],
#  766458: ['Japanese_rock_music_groups'],
#  767654: ['Japanese_rock_music_groups'],
#  767663: ['Japanese_rock_music_groups', 'Sony_Music_Japan_artists'],
#  768628: ['Japanese_rock_music_groups', 'All-female_bands'],
#  776290: ['Japanese_rock_music_groups'],
#  776470: ['Japanese_rock_music_groups', 'Tzadik_Records_artists'],
#  803399: ['Japanese_rock_music_groups', 'Japanese_musical_groups'],
#  837951: ['Japanese_rock_music_groups',
#   'Musical_quintets',
#   'Japanese_musical_groups',
#   'Sony_Music_Japan_artists'],
#  892984: ['Japanese_rock_music_groups',
#   'Japanese_musical_groups',
#   'Sony_Music_Japan_artists'],
#  893295: ['Japanese_rock_music_groups'],
#  930693: ['Japanese_rock_music_groups', 'Musical_quartets'],
#  941824: ['Japanese_rock_music_groups'],
#  968888: ['Japanese_rock_music_groups'],
#  994965: ['Japanese_rock_music_groups'],
#  1015175: ['Japanese_rock_music_groups'],
#  1071413: ['Japanese_rock_music_groups', 'Avex_Trax_artists'],
#  1074528: ['Japanese_rock_music_groups', 'Musical_trios'],
#  1172840: ['Japanese_rock_music_groups'],
#  1180772: ['Japanese_rock_music_groups', 'Sony_Music_Japan_artists'],
#  1189675: ['Japanese_rock_music_groups'],
#  1191705: ['Japanese_rock_music_groups', 'Sony_Music_Japan_artists'],
#  1191722: ['Japanese_rock_music_groups', 'Sony_Music_Japan_artists'],
#  1191729: ['Japanese_rock_music_groups', 'Japanese_musical_groups'],
#  1191773: ['Japanese_rock_music_groups',
#   'Japanese_musical_groups',
#   'People_from_Tokyo',
#   'Sony_Music_Japan_artists'],
#  1191793: ['Japanese_rock_music_groups'],
#  1191802: ['Japanese_rock_music_groups',
#   'Japanese_musical_groups',
#   'Garage_rock_groups',
#   'Sony_Music_Japan_artists',
#   'All-female_bands'],
#  1191803: ['Japanese_rock_music_groups', 'Sony_Music_Japan_artists'],
#  1191830: ['Japanese_rock_music_groups',
#   'Japanese_musical_groups',
#   'Sony_Music_Japan_artists'],
#  1191834: ['Japanese_rock_music_groups', 'Musical_quintets'],
#  1191846: ['Japanese_rock_music_groups', 'Japanese_musical_groups'],
#  1191865: ['Japanese_rock_music_groups'],
#  1191872: ['Japanese_rock_music_groups'],
#  1191892: ['Japanese_rock_music_groups', 'Musical_quartets'],
#  1191894: ['Japanese_rock_music_groups'],
#  1191968: ['Japanese_rock_music_groups',
#   'Musical_quartets',
#   'Japanese_musical_groups'],
#  1191982: ['Japanese_rock_music_groups'],
#  1200999: ['Japanese_rock_music_groups', 'Japanese_musical_groups'],
#  1201661: ['Japanese_rock_music_groups'],
#  1223001: ['Japanese_rock_music_groups', 'Tzadik_Records_artists'],
#  1223386: ['Japanese_rock_music_groups'],
#  1228101: ['Japanese_rock_music_groups',
#   'Musical_groups_established_in_1987',
#   'Garage_rock_groups',
#   'Musical_trios',
#   'Sony_Music_Japan_artists',
#   'Garage_punk'],
#  1228765: ['Japanese_rock_music_groups'],
#  1230067: ['Japanese_rock_music_groups'],
#  1287627: ['Japanese_rock_music_groups'],
#  1291827: ['Japanese_rock_music_groups', 'Sony_Music_Japan_artists'],
#  1316303: ['Japanese_rock_music_groups'],
#  1316323: ['Japanese_rock_music_groups',
#   'Japanese_musical_groups',
#   'Sony_Music_Japan_artists'],
#  1316336: ['Japanese_rock_music_groups'],
#  1338983: ['Japanese_rock_music_groups'],
#  1365308: ['Japanese_rock_music_groups',
#   'Glam_metal_musical_groups',
#   'All-female_bands'],
#  1371483: ['Japanese_rock_music_groups',
#   'Japanese_musical_groups',
#   'Sony_Music_Japan_artists',
#   'Tzadik_Records_artists'],
#  1378964: ['Japanese_rock_music_groups'],
#  1429259: ['Japanese_rock_music_groups'],
#  1450748: ['Japanese_rock_music_groups', 'Sony_Music_Japan_artists'],
#  1469725: ['Japanese_rock_music_groups'],
#  1471827: ['Japanese_rock_music_groups', 'Musical_quartets'],
#  1471852: ['Japanese_rock_music_groups', 'Japanese_musical_groups'],
#  1480239: ['Japanese_rock_music_groups', 'Sony_Music_Japan_artists'],
#  1514308: ['Japanese_rock_music_groups', 'Musical_groups_established_in_1987'],
#  1514474: ['Japanese_rock_music_groups', 'Musical_quartets'],
#  1550997: ['Japanese_rock_music_groups'],
#  1558831: ['Japanese_rock_music_groups'],
#  1559530: ['Japanese_rock_music_groups', 'Musical_groups_established_in_1986'],
#  1559624: ['Japanese_rock_music_groups'],
#  1569632: ['Japanese_rock_music_groups', 'Japanese_musicians'],
#  1584034: ['Japanese_rock_music_groups'],
#  1603244: ['Japanese_rock_music_groups',
#   'Musical_groups_established_in_1986',
#   'Japanese_musical_groups'],
#  1603704: ['Japanese_rock_music_groups'],
#  1624678: ['Japanese_rock_music_groups'],
#  1626820: ['Japanese_rock_music_groups', 'All-female_bands'],
#  1627203: ['Japanese_rock_music_groups'],
#  1627205: ['Japanese_rock_music_groups',
#   'People_from_Kanagawa_Prefecture',
#   'Musical_trios'],
#  1627232: ['Japanese_rock_music_groups'],
#  1627235: ['Japanese_rock_music_groups'],
#  1689739: ['Japanese_rock_music_groups', 'Musical_quartets'],
#  1717461: ['Japanese_rock_music_groups'],
#  1720375: ['Japanese_rock_music_groups'],
#  1742964: ['Japanese_rock_music_groups', 'Japanese_musical_groups'],
#  1745126: ['Japanese_rock_music_groups', 'Musical_sextets'],
#  1747547: ['Japanese_rock_music_groups',
#   'Musical_quartets',
#   'Japanese_musical_groups'],
#  1747565: ['Japanese_rock_music_groups', 'Musical_quintets'],
#  1747644: ['Japanese_rock_music_groups'],
#  1747919: ['Japanese_rock_music_groups', 'Musical_trios', 'Supergroups'],
#  1747921: ['Japanese_rock_music_groups'],
#  1747926: ['Japanese_rock_music_groups'],
#  1748616: ['Japanese_rock_music_groups',
#   'American_rock_music_groups',
#   'Video_game_composers'],
#  1749160: ['Japanese_rock_music_groups'],
#  1749503: ['Japanese_rock_music_groups', 'Avex_Trax_artists'],
#  1750117: ['Japanese_rock_music_groups',
#   'Musical_trios',
#   'Sony_Music_Japan_artists',
#   'All-female_bands'],
#  1750118: ['Japanese_rock_music_groups',
#   'Japanese_musical_groups',
#   'Sony_Music_Japan_artists'],
#  1754829: ['Japanese_rock_music_groups'],
#  1754956: ['Japanese_rock_music_groups'],
#  1758209: ['Japanese_rock_music_groups'],
#  1758884: ['Japanese_rock_music_groups', 'Sony_Music_Japan_artists'],
#  1759782: ['Japanese_rock_music_groups', 'Living_people'],
#  1789458: ['Japanese_rock_music_groups', 'Japanese_musical_groups'],
#  1941: ['Laboulbeniomycetes', 'Monotypic_fungi_genera'],
#  1942: ['Laboulbeniomycetes', 'Monotypic_fungi_genera'],
#  1943: ['Laboulbeniomycetes', 'Monotypic_fungi_genera'],
#  1944: ['Laboulbeniomycetes', 'Monotypic_fungi_genera'],
#  1945: ['Laboulbeniomycetes', 'Monotypic_fungi_genera'],
#  1947: ['Laboulbeniomycetes'],
#  1948: ['Laboulbeniomycetes'],
#  1949: ['Laboulbeniomycetes'],
#  1950: ['Laboulbeniomycetes'],
#  1951: ['Laboulbeniomycetes'],
#  1952: ['Laboulbeniomycetes'],
#  1953: ['Laboulbeniomycetes'],
#  1954: ['Laboulbeniomycetes'],
#  1955: ['Laboulbeniomycetes'],
#  1956: ['Laboulbeniomycetes'],
#  1957: ['Laboulbeniomycetes'],
#  1958: ['Laboulbeniomycetes'],
#  1959: ['Laboulbeniomycetes', 'Monotypic_fungi_genera'],
#  1960: ['Laboulbeniomycetes', 'Monotypic_fungi_genera'],
#  1961: ['Laboulbeniomycetes', 'Monotypic_fungi_genera'],
#  1962: ['Laboulbeniomycetes', 'Monotypic_fungi_genera'],
#  ...}

# %%
"""
reducing cat_per_pages dictionary 
to have the condition that only one page is linked to only one category. 

"""
one_cat_per_pages = {}
for key, elem in tqdm(cat_per_pages.items()):
    one_cat_per_pages[key] = random.choices(elem, k = 1)
# Out:
# 100%|██████████| 1791489/1791489 [00:09<00:00, 189780.98it/s]

# %%
one_cat_per_pages
# Out:
# {301: ['Buprestoidea'],
#  302: ['Buprestoidea'],
#  303: ['Buprestoidea'],
#  304: ['Buprestoidea'],
#  305: ['Buprestoidea'],
#  306: ['Buprestoidea'],
#  307: ['Buprestoidea'],
#  308: ['Buprestoidea'],
#  309: ['Buprestoidea'],
#  310: ['Buprestoidea'],
#  311: ['Buprestoidea'],
#  312: ['Buprestoidea'],
#  313: ['Buprestoidea'],
#  314: ['Buprestoidea'],
#  315: ['Buprestoidea'],
#  316: ['Buprestoidea'],
#  317: ['Buprestoidea'],
#  318: ['Buprestoidea'],
#  319: ['Buprestoidea'],
#  320: ['Buprestoidea'],
#  321: ['Buprestoidea'],
#  322: ['Buprestoidea'],
#  323: ['Buprestoidea'],
#  324: ['Buprestoidea'],
#  325: ['Buprestoidea'],
#  326: ['Buprestoidea'],
#  327: ['Buprestoidea'],
#  328: ['Buprestoidea'],
#  329: ['Buprestoidea'],
#  330: ['Buprestoidea'],
#  331: ['Buprestoidea'],
#  332: ['Buprestoidea'],
#  333: ['Buprestoidea'],
#  334: ['Buprestoidea'],
#  335: ['Buprestoidea'],
#  336: ['Buprestoidea'],
#  337: ['Buprestoidea'],
#  338: ['Buprestoidea'],
#  339: ['Buprestoidea'],
#  340: ['Buprestoidea'],
#  341: ['Buprestoidea'],
#  342: ['Buprestoidea'],
#  343: ['Buprestoidea'],
#  344: ['Buprestoidea'],
#  345: ['Buprestoidea'],
#  346: ['Buprestoidea'],
#  347: ['Buprestoidea'],
#  348: ['Buprestoidea'],
#  349: ['Buprestoidea'],
#  350: ['Buprestoidea'],
#  351: ['Buprestoidea'],
#  352: ['Buprestoidea'],
#  353: ['Buprestoidea'],
#  354: ['Buprestoidea'],
#  355: ['Buprestoidea'],
#  356: ['Buprestoidea'],
#  357: ['Buprestoidea'],
#  358: ['Buprestoidea'],
#  359: ['Buprestoidea'],
#  360: ['Buprestoidea'],
#  361: ['Buprestoidea'],
#  362: ['Buprestoidea'],
#  363: ['Buprestoidea'],
#  364: ['Buprestoidea'],
#  365: ['Buprestoidea'],
#  366: ['Buprestoidea'],
#  367: ['Buprestoidea'],
#  368: ['Buprestoidea'],
#  369: ['Buprestoidea'],
#  370: ['Buprestoidea'],
#  371: ['Buprestoidea'],
#  372: ['Buprestoidea'],
#  373: ['Buprestoidea'],
#  374: ['Buprestoidea'],
#  375: ['Buprestoidea'],
#  376: ['Buprestoidea'],
#  377: ['Buprestoidea'],
#  378: ['Buprestoidea'],
#  379: ['Buprestoidea'],
#  380: ['Buprestoidea'],
#  381: ['Buprestoidea'],
#  382: ['Buprestoidea'],
#  383: ['Buprestoidea'],
#  384: ['Buprestoidea'],
#  385: ['Buprestoidea'],
#  386: ['Buprestoidea'],
#  387: ['Buprestoidea'],
#  388: ['Buprestoidea'],
#  389: ['Buprestoidea'],
#  390: ['Buprestoidea'],
#  391: ['Buprestoidea'],
#  392: ['Buprestoidea'],
#  393: ['Buprestoidea'],
#  394: ['Buprestoidea'],
#  395: ['Buprestoidea'],
#  396: ['Buprestoidea'],
#  397: ['Buprestoidea'],
#  398: ['Buprestoidea'],
#  399: ['Buprestoidea'],
#  400: ['Buprestoidea'],
#  401: ['Buprestoidea'],
#  402: ['Buprestoidea'],
#  403: ['Buprestoidea'],
#  404: ['Buprestoidea'],
#  405: ['Buprestoidea'],
#  406: ['Buprestoidea'],
#  407: ['Buprestoidea'],
#  408: ['Buprestoidea'],
#  409: ['Buprestoidea'],
#  410: ['Buprestoidea'],
#  411: ['Buprestoidea'],
#  412: ['Buprestoidea'],
#  413: ['Buprestoidea'],
#  414: ['Buprestoidea'],
#  415: ['Buprestoidea'],
#  416: ['Buprestoidea'],
#  417: ['Buprestoidea'],
#  418: ['Buprestoidea'],
#  419: ['Buprestoidea'],
#  420: ['Buprestoidea'],
#  421: ['Buprestoidea'],
#  422: ['Buprestoidea'],
#  423: ['Buprestoidea'],
#  424: ['Buprestoidea'],
#  425: ['Buprestoidea'],
#  426: ['Buprestoidea'],
#  427: ['Buprestoidea'],
#  428: ['Buprestoidea'],
#  429: ['Buprestoidea'],
#  430: ['Buprestoidea'],
#  431: ['Buprestoidea'],
#  432: ['Buprestoidea'],
#  433: ['Buprestoidea'],
#  434: ['Buprestoidea'],
#  435: ['Buprestoidea'],
#  436: ['Buprestoidea'],
#  437: ['Buprestoidea'],
#  438: ['Buprestoidea'],
#  439: ['Buprestoidea'],
#  440: ['Buprestoidea'],
#  441: ['Buprestoidea'],
#  442: ['Buprestoidea'],
#  443: ['Buprestoidea'],
#  444: ['Buprestoidea'],
#  445: ['Buprestoidea'],
#  446: ['Buprestoidea'],
#  447: ['Buprestoidea'],
#  448: ['Buprestoidea'],
#  449: ['Buprestoidea'],
#  450: ['Buprestoidea'],
#  451: ['Buprestoidea'],
#  452: ['Buprestoidea'],
#  453: ['Buprestoidea'],
#  454: ['Buprestoidea'],
#  455: ['Buprestoidea'],
#  456: ['Buprestoidea'],
#  457: ['Buprestoidea'],
#  458: ['Buprestoidea'],
#  459: ['Buprestoidea'],
#  460: ['Buprestoidea'],
#  461: ['Buprestoidea'],
#  462: ['Buprestoidea'],
#  463: ['Buprestoidea'],
#  464: ['Buprestoidea'],
#  465: ['Buprestoidea'],
#  466: ['Buprestoidea'],
#  467: ['Buprestoidea'],
#  468: ['Buprestoidea'],
#  469: ['Buprestoidea'],
#  470: ['Buprestoidea'],
#  471: ['Buprestoidea'],
#  472: ['Buprestoidea'],
#  473: ['Buprestoidea'],
#  474: ['Buprestoidea'],
#  475: ['Buprestoidea'],
#  476: ['Buprestoidea'],
#  477: ['Buprestoidea'],
#  478: ['Buprestoidea'],
#  479: ['Buprestoidea'],
#  480: ['Buprestoidea'],
#  481: ['Buprestoidea'],
#  482: ['Buprestoidea'],
#  483: ['Buprestoidea'],
#  484: ['Buprestoidea'],
#  485: ['Buprestoidea'],
#  486: ['Buprestoidea'],
#  487: ['Buprestoidea'],
#  488: ['Buprestoidea'],
#  489: ['Buprestoidea'],
#  490: ['Buprestoidea'],
#  491: ['Buprestoidea'],
#  492: ['Buprestoidea'],
#  493: ['Buprestoidea'],
#  494: ['Buprestoidea'],
#  495: ['Buprestoidea'],
#  496: ['Buprestoidea'],
#  497: ['Buprestoidea'],
#  498: ['Buprestoidea'],
#  499: ['Buprestoidea'],
#  500: ['Buprestoidea'],
#  501: ['Buprestoidea'],
#  502: ['Buprestoidea'],
#  503: ['Buprestoidea'],
#  504: ['Buprestoidea'],
#  505: ['Buprestoidea'],
#  506: ['Buprestoidea'],
#  507: ['Buprestoidea'],
#  508: ['Buprestoidea'],
#  509: ['Buprestoidea'],
#  510: ['Buprestoidea'],
#  511: ['Buprestoidea'],
#  512: ['Buprestoidea'],
#  513: ['Buprestoidea'],
#  514: ['Buprestoidea'],
#  515: ['Buprestoidea'],
#  516: ['Buprestoidea'],
#  517: ['Buprestoidea'],
#  518: ['Buprestoidea'],
#  519: ['Buprestoidea'],
#  520: ['Buprestoidea'],
#  521: ['Buprestoidea'],
#  522: ['Buprestoidea'],
#  523: ['Buprestoidea'],
#  524: ['Buprestoidea'],
#  525: ['Buprestoidea'],
#  526: ['Buprestoidea'],
#  527: ['Buprestoidea'],
#  528: ['Buprestoidea'],
#  529: ['Buprestoidea'],
#  530: ['Buprestoidea'],
#  531: ['Buprestoidea'],
#  532: ['Buprestoidea'],
#  533: ['Buprestoidea'],
#  534: ['Buprestoidea'],
#  535: ['Buprestoidea'],
#  536: ['Buprestoidea'],
#  537: ['Buprestoidea'],
#  538: ['Buprestoidea'],
#  539: ['Buprestoidea'],
#  540: ['Buprestoidea'],
#  541: ['Buprestoidea'],
#  542: ['Buprestoidea'],
#  543: ['Buprestoidea'],
#  544: ['Buprestoidea'],
#  545: ['Buprestoidea'],
#  546: ['Buprestoidea'],
#  547: ['Buprestoidea'],
#  548: ['Buprestoidea'],
#  549: ['Buprestoidea'],
#  550: ['Buprestoidea'],
#  551: ['Buprestoidea'],
#  552: ['Buprestoidea'],
#  553: ['Buprestoidea'],
#  554: ['Buprestoidea'],
#  555: ['Buprestoidea'],
#  556: ['Buprestoidea'],
#  557: ['Buprestoidea'],
#  558: ['Buprestoidea'],
#  559: ['Buprestoidea'],
#  560: ['Buprestoidea'],
#  561: ['Buprestoidea'],
#  562: ['Buprestoidea'],
#  563: ['Buprestoidea'],
#  564: ['Buprestoidea'],
#  565: ['Buprestoidea'],
#  566: ['Buprestoidea'],
#  567: ['Buprestoidea'],
#  568: ['Buprestoidea'],
#  569: ['Buprestoidea'],
#  570: ['Buprestoidea'],
#  571: ['Buprestoidea'],
#  572: ['Buprestoidea'],
#  573: ['Buprestoidea'],
#  574: ['Buprestoidea'],
#  575: ['Buprestoidea'],
#  576: ['Buprestoidea'],
#  577: ['Buprestoidea'],
#  578: ['Buprestoidea'],
#  579: ['Buprestoidea'],
#  580: ['Buprestoidea'],
#  581: ['Buprestoidea'],
#  582: ['Buprestoidea'],
#  583: ['Buprestoidea'],
#  584: ['Buprestoidea'],
#  585: ['Buprestoidea'],
#  586: ['Buprestoidea'],
#  587: ['Buprestoidea'],
#  588: ['Buprestoidea'],
#  589: ['Buprestoidea'],
#  590: ['Buprestoidea'],
#  591: ['Buprestoidea'],
#  592: ['Buprestoidea'],
#  593: ['Buprestoidea'],
#  594: ['Buprestoidea'],
#  595: ['Buprestoidea'],
#  596: ['Buprestoidea'],
#  597: ['Buprestoidea'],
#  598: ['Buprestoidea'],
#  599: ['Buprestoidea'],
#  600: ['Buprestoidea'],
#  601: ['Buprestoidea'],
#  602: ['Buprestoidea'],
#  603: ['Buprestoidea'],
#  604: ['Buprestoidea'],
#  605: ['Buprestoidea'],
#  606: ['Buprestoidea'],
#  607: ['Buprestoidea'],
#  608: ['Buprestoidea'],
#  609: ['Buprestoidea'],
#  610: ['Buprestoidea'],
#  611: ['Buprestoidea'],
#  612: ['Buprestoidea'],
#  613: ['Buprestoidea'],
#  614: ['Buprestoidea'],
#  615: ['Buprestoidea'],
#  616: ['Buprestoidea'],
#  617: ['Buprestoidea'],
#  618: ['Buprestoidea'],
#  619: ['Buprestoidea'],
#  620: ['Buprestoidea'],
#  621: ['Buprestoidea'],
#  622: ['Buprestoidea'],
#  623: ['Buprestoidea'],
#  624: ['Buprestoidea'],
#  625: ['Buprestoidea'],
#  626: ['Buprestoidea'],
#  627: ['Buprestoidea'],
#  628: ['Buprestoidea'],
#  629: ['Buprestoidea'],
#  630: ['Buprestoidea'],
#  631: ['Buprestoidea'],
#  632: ['Buprestoidea'],
#  633: ['Buprestoidea'],
#  634: ['Buprestoidea'],
#  635: ['Buprestoidea'],
#  636: ['Buprestoidea'],
#  637: ['Buprestoidea'],
#  638: ['Buprestoidea'],
#  639: ['Buprestoidea'],
#  640: ['Buprestoidea'],
#  641: ['Buprestoidea'],
#  642: ['Buprestoidea'],
#  643: ['Buprestoidea'],
#  644: ['Buprestoidea'],
#  645: ['Buprestoidea'],
#  646: ['Buprestoidea'],
#  647: ['Buprestoidea'],
#  648: ['Buprestoidea'],
#  649: ['Buprestoidea'],
#  650: ['Buprestoidea'],
#  651: ['Buprestoidea'],
#  652: ['Buprestoidea'],
#  653: ['Buprestoidea'],
#  654: ['Buprestoidea'],
#  655: ['Buprestoidea'],
#  656: ['Buprestoidea'],
#  657: ['Buprestoidea'],
#  658: ['Buprestoidea'],
#  659: ['Buprestoidea'],
#  660: ['Buprestoidea'],
#  661: ['Buprestoidea'],
#  662: ['Buprestoidea'],
#  663: ['Buprestoidea'],
#  664: ['Buprestoidea'],
#  665: ['Buprestoidea'],
#  666: ['Buprestoidea'],
#  667: ['Buprestoidea'],
#  668: ['Buprestoidea'],
#  669: ['Buprestoidea'],
#  670: ['Buprestoidea'],
#  671: ['Buprestoidea'],
#  672: ['Buprestoidea'],
#  673: ['Buprestoidea'],
#  674: ['Buprestoidea'],
#  675: ['Buprestoidea'],
#  676: ['Buprestoidea'],
#  677: ['Buprestoidea'],
#  678: ['Buprestoidea'],
#  679: ['Buprestoidea'],
#  680: ['Buprestoidea'],
#  681: ['Buprestoidea'],
#  682: ['Buprestoidea'],
#  683: ['Buprestoidea'],
#  684: ['Buprestoidea'],
#  685: ['Buprestoidea'],
#  686: ['Buprestoidea'],
#  687: ['Buprestoidea'],
#  688: ['Buprestoidea'],
#  689: ['Buprestoidea'],
#  690: ['Buprestoidea'],
#  691: ['Buprestoidea'],
#  692: ['Buprestoidea'],
#  693: ['Buprestoidea'],
#  694: ['Buprestoidea'],
#  695: ['Buprestoidea'],
#  696: ['Buprestoidea'],
#  697: ['Buprestoidea'],
#  698: ['Buprestoidea'],
#  699: ['Buprestoidea'],
#  700: ['Buprestoidea'],
#  701: ['Buprestoidea'],
#  702: ['Buprestoidea'],
#  703: ['Buprestoidea'],
#  704: ['Buprestoidea'],
#  705: ['Buprestoidea'],
#  706: ['Buprestoidea'],
#  707: ['Buprestoidea'],
#  708: ['Buprestoidea'],
#  709: ['Buprestoidea'],
#  710: ['Buprestoidea'],
#  711: ['Buprestoidea'],
#  712: ['Buprestoidea'],
#  713: ['Buprestoidea'],
#  714: ['Buprestoidea'],
#  715: ['Buprestoidea'],
#  716: ['Buprestoidea'],
#  717: ['Buprestoidea'],
#  718: ['Buprestoidea'],
#  719: ['Buprestoidea'],
#  720: ['Buprestoidea'],
#  721: ['Buprestoidea'],
#  722: ['Buprestoidea'],
#  723: ['Buprestoidea'],
#  724: ['Buprestoidea'],
#  725: ['Buprestoidea'],
#  726: ['Buprestoidea'],
#  727: ['Buprestoidea'],
#  728: ['Buprestoidea'],
#  729: ['Buprestoidea'],
#  730: ['Buprestoidea'],
#  731: ['Buprestoidea'],
#  732: ['Buprestoidea'],
#  733: ['Buprestoidea'],
#  734: ['Buprestoidea'],
#  735: ['Buprestoidea'],
#  736: ['Buprestoidea'],
#  737: ['Buprestoidea'],
#  738: ['Buprestoidea'],
#  739: ['Buprestoidea'],
#  740: ['Buprestoidea'],
#  741: ['Buprestoidea'],
#  742: ['Buprestoidea'],
#  743: ['Buprestoidea'],
#  744: ['Buprestoidea'],
#  745: ['Buprestoidea'],
#  746: ['Buprestoidea'],
#  747: ['Buprestoidea'],
#  748: ['Buprestoidea'],
#  749: ['Buprestoidea'],
#  750: ['Buprestoidea'],
#  751: ['Buprestoidea'],
#  752: ['Buprestoidea'],
#  753: ['Buprestoidea'],
#  754: ['Buprestoidea'],
#  755: ['Buprestoidea'],
#  756: ['Buprestoidea'],
#  757: ['Buprestoidea'],
#  758: ['Buprestoidea'],
#  759: ['Buprestoidea'],
#  760: ['Buprestoidea'],
#  761: ['Buprestoidea'],
#  762: ['Buprestoidea'],
#  763: ['Buprestoidea'],
#  764: ['Buprestoidea'],
#  765: ['Buprestoidea'],
#  766: ['Buprestoidea'],
#  767: ['Buprestoidea'],
#  768: ['Buprestoidea'],
#  769: ['Buprestoidea'],
#  770: ['Buprestoidea'],
#  771: ['Buprestoidea'],
#  772: ['Buprestoidea'],
#  773: ['Buprestoidea'],
#  774: ['Buprestoidea'],
#  775: ['Buprestoidea'],
#  776: ['Buprestoidea'],
#  777: ['Buprestoidea'],
#  778: ['Buprestoidea'],
#  779: ['Buprestoidea'],
#  780: ['Buprestoidea'],
#  781: ['Buprestoidea'],
#  782: ['Buprestoidea'],
#  783: ['Buprestoidea'],
#  784: ['Buprestoidea'],
#  785: ['Buprestoidea'],
#  786: ['Buprestoidea'],
#  787: ['Buprestoidea'],
#  788: ['Buprestoidea'],
#  789: ['Buprestoidea'],
#  790: ['Buprestoidea'],
#  791: ['Buprestoidea'],
#  792: ['Buprestoidea'],
#  793: ['Buprestoidea'],
#  794: ['Buprestoidea'],
#  795: ['Buprestoidea'],
#  796: ['Buprestoidea'],
#  797: ['Buprestoidea'],
#  798: ['Buprestoidea'],
#  799: ['Buprestoidea'],
#  800: ['Buprestoidea'],
#  801: ['Buprestoidea'],
#  802: ['Buprestoidea'],
#  803: ['Buprestoidea'],
#  804: ['Buprestoidea'],
#  805: ['Buprestoidea'],
#  806: ['Buprestoidea'],
#  807: ['Buprestoidea'],
#  808: ['Buprestoidea'],
#  809: ['Buprestoidea'],
#  810: ['Buprestoidea'],
#  811: ['Buprestoidea'],
#  812: ['Buprestoidea'],
#  813: ['Buprestoidea'],
#  814: ['Buprestoidea'],
#  815: ['Buprestoidea'],
#  816: ['Buprestoidea'],
#  817: ['Buprestoidea'],
#  818: ['Buprestoidea'],
#  819: ['Buprestoidea'],
#  820: ['Buprestoidea'],
#  821: ['Buprestoidea'],
#  822: ['Buprestoidea'],
#  823: ['Buprestoidea'],
#  824: ['Buprestoidea'],
#  825: ['Buprestoidea'],
#  826: ['Buprestoidea'],
#  827: ['Buprestoidea'],
#  828: ['Buprestoidea'],
#  829: ['Buprestoidea'],
#  830: ['Buprestoidea'],
#  831: ['Buprestoidea'],
#  832: ['Buprestoidea'],
#  833: ['Buprestoidea'],
#  834: ['Buprestoidea'],
#  835: ['Buprestoidea'],
#  836: ['Buprestoidea'],
#  837: ['Buprestoidea'],
#  838: ['Buprestoidea'],
#  839: ['Buprestoidea'],
#  840: ['Buprestoidea'],
#  841: ['Buprestoidea'],
#  842: ['Buprestoidea'],
#  1791374: ['Buprestoidea'],
#  1056: ['English_engineers'],
#  1057: ['People_from_Worcester'],
#  1058: ['British_writers'],
#  1059: ["English_children's_writers"],
#  1060: ['People_from_Worcester'],
#  60971: ['16th-century_English_people'],
#  76515: ['English_footballers'],
#  76871: ['People_from_Worcester'],
#  78094: ['People_from_Worcester'],
#  79069: ['Nuneaton_Town_F.C._players'],
#  79139: ['Association_football_forwards'],
#  79143: ['English_footballers'],
#  80237: ['The_Football_League_players'],
#  84108: ['Wolverhampton_Wanderers_F.C._players'],
#  84354: ['Living_people'],
#  84740: ['English_football_referees'],
#  85268: ['People_from_Worcester'],
#  85767: ['Rochdale_A.F.C._players'],
#  89734: ['People_from_Worcester'],
#  90171: ['Chelmsford_City_F.C._players'],
#  95330: ['People_from_Worcester'],
#  158412: ['People_from_Worcester'],
#  166087: ['People_from_Worcester'],
#  194583: ['Living_people'],
#  196217: ['People_from_Worcester'],
#  216650: ['Year_of_birth_missing_(living_people)'],
#  216770: ['English_composers'],
#  348758: ['People_from_Worcester'],
#  350247: ['Fellows_of_New_College,_Oxford'],
#  350259: ['18th-century_English_people'],
#  350608: ['Physical_chemists'],
#  372883: ['Landscape_artists'],
#  377480: ['People_from_Worcester'],
#  437692: ['British_civil_engineers'],
#  449761: ['Living_people'],
#  449809: ['16th-century_English_people'],
#  454664: ['People_from_Worcester'],
#  494420: ['Olympic_field_hockey_players_of_Great_Britain'],
#  499532: ['Living_people'],
#  527094: ['Living_people'],
#  537220: ['UK_MPs_18681874'],
#  538870: ['UK_MPs_20012005'],
#  540020: ['People_from_Worcester'],
#  541169: ['Liberal_Party_(UK)_MPs'],
#  544700: ['English_medical_doctors'],
#  544701: ['Royal_Navy_admirals'],
#  544738: ['People_from_Worcester'],
#  544888: ['People_from_Worcester'],
#  546749: ['People_from_Worcester'],
#  654238: ['People_from_Worcester'],
#  669757: ['People_from_Worcester'],
#  721089: ['People_from_Worcester'],
#  721539: ["Chevaliers_of_the_Lgion_d'honneur"],
#  791902: ['English_illustrators'],
#  799357: ['English_botanists'],
#  826926: ['Old_Wykehamists'],
#  827472: ['Living_people'],
#  827479: ['Women_novelists'],
#  830268: ["Christ's_Hospital_Old_Blues"],
#  883273: ['Association_football_goalkeepers'],
#  919797: ['English_businesspeople'],
#  971629: ['People_from_Worcester'],
#  979026: ['Royal_Academicians'],
#  995033: ['People_from_Worcester'],
#  998609: ['People_from_Worcester'],
#  1011834: ['English_cyclists'],
#  1033464: ['Living_people'],
#  1043638: ['English_film_actors'],
#  1043983: ['Old_Amplefordians'],
#  1047370: ['Living_people'],
#  1112567: ['British_Jews'],
#  1142375: ['Bishops_of_Worcester'],
#  1143260: ['People_of_the_Tudor_period'],
#  1170545: ['People_from_Worcester'],
#  1178634: ['People_from_Worcester'],
#  1194242: ['The_Guardian_journalists'],
#  1260349: ['English_academics'],
#  1284729: ['English_actors'],
#  1287891: ['People_from_Worcester'],
#  1287952: ['British_radio_personalities'],
#  1342966: ['People_from_Worcester'],
#  1343202: ['People_from_Worcester'],
#  1385068: ['Royal_Academicians'],
#  1390440: ['English_Anglican_priests'],
#  1445619: ['English_cricketers'],
#  1470844: ['People_from_Worcester'],
#  1472916: ['People_from_Worcester'],
#  1499171: ['Academics_of_the_University_of_Birmingham'],
#  1506216: ['People_from_Worcester'],
#  1516445: ['People_of_the_Tudor_period'],
#  1525160: ['Living_people'],
#  1525827: ['People_from_Worcester'],
#  1527616: ['England_international_rugby_union_players'],
#  1565695: ['People_from_Worcester'],
#  1568124: ['Olympic_swimmers_of_Great_Britain'],
#  1610622: ['People_from_Worcester'],
#  1646864: ['People_from_Worcester'],
#  1653449: ['Explorers_of_Africa'],
#  1667832: ['People_from_Worcester'],
#  1715203: ['Commanders_of_the_Order_of_the_British_Empire'],
#  1779646: ['8th-century_bishops'],
#  1780461: ['People_from_Worcester'],
#  1781093: ['People_from_Worcester'],
#  971: ['Skin_conditions_resulting_from_physical_factors'],
#  973: ['Skin_conditions_resulting_from_physical_factors'],
#  1166: ['Skin_conditions_resulting_from_physical_factors'],
#  1167: ['Skin_conditions_resulting_from_physical_factors'],
#  1168: ['Skin_conditions_resulting_from_physical_factors'],
#  1169: ['Skin_conditions_resulting_from_physical_factors'],
#  1170: ['Skin_conditions_resulting_from_physical_factors'],
#  1171: ['Skin_conditions_resulting_from_physical_factors'],
#  1172: ['Skin_conditions_resulting_from_physical_factors'],
#  1173: ['Skin_conditions_resulting_from_physical_factors'],
#  1174: ['Skin_conditions_resulting_from_physical_factors'],
#  1175: ['Skin_conditions_resulting_from_physical_factors'],
#  1176: ['Skin_conditions_resulting_from_physical_factors'],
#  1177: ['Skin_conditions_resulting_from_physical_factors'],
#  2810: ['Skin_conditions_resulting_from_physical_factors'],
#  3574: ['Tort_law'],
#  5230: ['Skin_conditions_resulting_from_physical_factors'],
#  5319: ['Skin_conditions_resulting_from_physical_factors'],
#  6358: ['Skin_conditions_resulting_from_physical_factors'],
#  6970: ['Skin_conditions_resulting_from_physical_factors'],
#  8220: ['1990s_fashion'],
#  8587: ['Skin_conditions_resulting_from_physical_factors'],
#  9120: ['Skin_conditions_resulting_from_physical_factors'],
#  9201: ['Skin_conditions_resulting_from_physical_factors'],
#  9348: ['Medical_emergencies'],
#  9440: ['Medical_signs'],
#  9495: ['Medical_emergencies'],
#  9636: ['Skin_conditions_resulting_from_physical_factors'],
#  9642: ['Skin_conditions_resulting_from_physical_factors'],
#  10053: ['Skin_conditions_resulting_from_physical_factors'],
#  10897: ['Skin_conditions_resulting_from_physical_factors'],
#  11564: ['Skin_conditions_resulting_from_physical_factors'],
#  12184: ['Skin_conditions_resulting_from_physical_factors'],
#  15516: ['Skin_conditions_resulting_from_physical_factors'],
#  40429: ['Skin_conditions_resulting_from_physical_factors'],
#  150415: ['Skin_conditions_resulting_from_physical_factors'],
#  354222: ['Skin_conditions_resulting_from_physical_factors'],
#  354224: ['Skin_conditions_resulting_from_physical_factors'],
#  369562: ['Skin_conditions_resulting_from_physical_factors'],
#  428725: ['Paper'],
#  851858: ['Skin_conditions_resulting_from_physical_factors'],
#  885574: ['Skin_conditions_resulting_from_physical_factors'],
#  1003941: ['Skin_conditions_resulting_from_physical_factors'],
#  1032218: ['Skin_conditions_resulting_from_physical_factors'],
#  1073413: ['Skin_conditions_resulting_from_physical_factors'],
#  1087184: ['Skin_conditions_resulting_from_physical_factors'],
#  1240875: ['Skin_conditions_resulting_from_physical_factors'],
#  1293461: ['Skin_conditions_resulting_from_physical_factors'],
#  1316419: ['Skin_conditions_resulting_from_physical_factors'],
#  1364950: ['Skin_conditions_resulting_from_physical_factors'],
#  1378135: ['Skin_conditions_resulting_from_physical_factors'],
#  1378136: ['Skin_conditions_resulting_from_physical_factors'],
#  1450546: ['Skin_conditions_resulting_from_physical_factors'],
#  1450547: ['Skin_conditions_resulting_from_physical_factors'],
#  1475467: ['Skin_conditions_resulting_from_physical_factors'],
#  1523943: ['Skin_conditions_resulting_from_physical_factors'],
#  1523944: ['Skin_conditions_resulting_from_physical_factors'],
#  1523945: ['Skin_conditions_resulting_from_physical_factors'],
#  1523946: ['Skin_conditions_resulting_from_physical_factors'],
#  1584014: ['Skin_conditions_resulting_from_physical_factors'],
#  1631187: ['Skin_conditions_resulting_from_physical_factors'],
#  1631188: ['Skin_conditions_resulting_from_physical_factors'],
#  1663489: ['Skin_conditions_resulting_from_physical_factors'],
#  1692063: ['Skin_conditions_resulting_from_physical_factors'],
#  1692064: ['Skin_conditions_resulting_from_physical_factors'],
#  1705410: ['Skin_conditions_resulting_from_physical_factors'],
#  1705411: ['Skin_conditions_resulting_from_physical_factors'],
#  1705412: ['Skin_conditions_resulting_from_physical_factors'],
#  1713424: ['Skin_conditions_resulting_from_physical_factors'],
#  1297: ['Visual_kei_bands'],
#  1300: ['Musical_groups_established_in_1992'],
#  1311: ['Japanese_musical_groups'],
#  1312: ['Musical_quintets'],
#  1313: ['Visual_kei_bands'],
#  1314: ['Visual_kei_bands'],
#  1315: ['Visual_kei_bands'],
#  1316: ['Visual_kei_bands'],
#  1319: ['Visual_kei_bands'],
#  1320: ['Sony_Music_Japan_artists'],
#  1321: ['Visual_kei_bands'],
#  1322: ['Visual_kei_bands'],
#  1323: ['Japanese_rock_music_groups'],
#  1324: ['Visual_kei_bands'],
#  1325: ['Musical_quartets'],
#  1326: ['Visual_kei_bands'],
#  1327: ['Musical_quintets'],
#  1328: ['Visual_kei_bands'],
#  1329: ['Visual_kei_bands'],
#  1330: ['Japanese_rock_music_groups'],
#  1331: ['Visual_kei_bands'],
#  1332: ['Visual_kei_bands'],
#  1333: ['Musical_quartets'],
#  1334: ['Visual_kei_bands'],
#  1335: ['Japanese_rock_music_groups'],
#  1336: ['Visual_kei_bands'],
#  1337: ['Japanese_musical_groups'],
#  1338: ['Musical_quintets'],
#  1339: ['Japanese_rock_music_groups'],
#  1340: ['Visual_kei_bands'],
#  1341: ['Visual_kei_bands'],
#  1342: ['Visual_kei_bands'],
#  1343: ['Visual_kei_bands'],
#  1345: ['Visual_kei_bands'],
#  1346: ['Japanese_rock_music_groups'],
#  1348: ['Visual_kei_bands'],
#  1349: ['Japanese_rock_music_groups'],
#  1350: ['Visual_kei_bands'],
#  1351: ['Japanese_rock_music_groups'],
#  1352: ['Japanese_rock_music_groups'],
#  1353: ['Japanese_rock_music_groups'],
#  1354: ['Visual_kei_bands'],
#  1356: ['Japanese_rock_music_groups'],
#  1357: ['Visual_kei_bands'],
#  1358: ['Japanese_rock_music_groups'],
#  1359: ['Japanese_rock_music_groups'],
#  1361: ['Musical_quartets'],
#  1363: ['Avex_Trax_artists'],
#  1364: ['Visual_kei_bands'],
#  1365: ['Japanese_rock_music_groups'],
#  1366: ['Japanese_rock_music_groups'],
#  1367: ['Visual_kei_bands'],
#  1368: ['Japanese_rock_music_groups'],
#  1369: ['Visual_kei_bands'],
#  1371: ['Japanese_rock_music_groups'],
#  1372: ['Japanese_musical_groups'],
#  1374: ['Visual_kei_bands'],
#  1375: ['Japanese_musical_groups'],
#  1376: ['Visual_kei_bands'],
#  1377: ['Japanese_rock_music_groups'],
#  1378: ['Musical_quartets'],
#  1380: ['Japanese_rock_music_groups'],
#  1383: ['Visual_kei_bands'],
#  1385: ['Japanese_rock_music_groups'],
#  1387: ['Sony_Music_Japan_artists'],
#  1390: ['Japanese_rock_music_groups'],
#  1393: ['Japanese_musical_groups'],
#  1395: ['Japanese_rock_music_groups'],
#  1403: ['Supergroups'],
#  1404: ['Musical_groups_established_in_2004'],
#  1410: ['Musical_quartets'],
#  1411: ['Visual_kei_bands'],
#  1418: ['Visual_kei_bands'],
#  1427: ['Musical_trios'],
#  1429: ['Musical_quartets'],
#  1431: ['Japanese_rock_music_groups'],
#  1435: ['Japanese_musical_groups'],
#  1440: ['Visual_kei_bands'],
#  1441: ['Visual_kei_bands'],
#  1446: ['Visual_kei_bands'],
#  1455: ['Visual_kei_bands'],
#  1461: ['Visual_kei_bands'],
#  1466: ['Visual_kei_bands'],
#  1473: ['Musical_quintets'],
#  1513: ['Japanese_rock_music_groups'],
#  562072: ['Japanese_musical_groups'],
#  604876: ['Musical_quartets'],
#  604884: ['Japanese_rock_music_groups'],
#  604888: ['Visual_kei_bands'],
#  635747: ['Japanese_rock_music_groups'],
#  657073: ['Visual_kei_bands'],
#  719336: ['Visual_kei_bands'],
#  751685: ['Musical_quartets'],
#  773402: ['Japanese_rock_music_groups'],
#  800357: ['All-female_bands'],
#  883789: ['Avex_Trax_artists'],
#  1002565: ['Japanese_musical_groups'],
#  1230384: ['Visual_kei_bands'],
#  1368113: ['Visual_kei_bands'],
#  1627518: ['Visual_kei_bands'],
#  1747657: ['Visual_kei_bands'],
#  1754961: ['Avex_Trax_artists'],
#  1763149: ['Musical_groups_established_in_1999'],
#  1360: ['Musical_quartets'],
#  1389: ['Japanese_rock_music_groups'],
#  1392: ['Japanese_musical_groups'],
#  1396: ['Japanese_rock_music_groups'],
#  1397: ['Japanese_rock_music_groups'],
#  1399: ['Musical_groups_established_in_1999'],
#  1400: ['Japanese_rock_music_groups'],
#  1402: ['Japanese_rock_music_groups'],
#  1408: ['All-female_bands'],
#  1409: ['Japanese_rock_music_groups'],
#  1414: ['Japanese_rock_music_groups'],
#  1417: ['Sony_Music_Japan_artists'],
#  1422: ['Japanese_rock_music_groups'],
#  1424: ['Japanese_musical_groups'],
#  1425: ['Japanese_rock_music_groups'],
#  1426: ['Japanese_rock_music_groups'],
#  1430: ['Japanese_rock_music_groups'],
#  1434: ['Musical_quartets'],
#  1436: ['Japanese_rock_music_groups'],
#  1437: ['Japanese_rock_music_groups'],
#  1439: ['Japanese_rock_music_groups'],
#  1469: ['Japanese_rock_music_groups'],
#  1488: ['Japanese_rock_music_groups'],
#  1491: ['Japanese_rock_music_groups'],
#  1492: ['Japanese_rock_music_groups'],
#  1499: ['Japanese_rock_music_groups'],
#  1500: ['Japanese_rock_music_groups'],
#  1501: ['Japanese_rock_music_groups'],
#  1506: ['Japanese_rock_music_groups'],
#  1509: ['Japanese_rock_music_groups'],
#  140768: ['Japanese_rock_music_groups'],
#  151198: ['Japanese_rock_music_groups'],
#  153001: ['Japanese_rock_music_groups'],
#  153029: ['Japanese_rock_music_groups'],
#  153031: ['Japanese_musical_groups'],
#  153036: ['Japanese_rock_music_groups'],
#  153504: ['Sony_Music_Japan_artists'],
#  154490: ['Japanese_rock_music_groups'],
#  208880: ['Japanese_rock_music_groups'],
#  310454: ['Japanese_musical_groups'],
#  395576: ['Japanese_rock_music_groups'],
#  451504: ['Japanese_rock_music_groups'],
#  522949: ['Japanese_rock_music_groups'],
#  559569: ['Japanese_rock_music_groups'],
#  562292: ['Japanese_rock_music_groups'],
#  564607: ['Musical_quintets'],
#  635741: ['Japanese_rock_music_groups'],
#  635742: ['Japanese_rock_music_groups'],
#  651191: ['Japanese_rock_music_groups'],
#  651200: ['Japanese_rock_music_groups'],
#  676478: ['Japanese_rock_music_groups'],
#  689452: ['Japanese_rock_music_groups'],
#  691204: ['Japanese_rock_music_groups'],
#  694134: ['Musical_groups_established_in_1986'],
#  694156: ['Japanese_rock_music_groups'],
#  694844: ['Japanese_rock_music_groups'],
#  705049: ['Japanese_rock_music_groups'],
#  705061: ['Musical_quartets'],
#  718774: ['Japanese_rock_music_groups'],
#  724416: ['Japanese_rock_music_groups'],
#  734210: ['Japanese_rock_music_groups'],
#  739279: ['Japanese_musical_groups'],
#  741099: ['Japanese_rock_music_groups'],
#  742287: ['Japanese_rock_music_groups'],
#  749516: ['Garage_punk'],
#  766458: ['Japanese_rock_music_groups'],
#  767654: ['Japanese_rock_music_groups'],
#  767663: ['Sony_Music_Japan_artists'],
#  768628: ['All-female_bands'],
#  776290: ['Japanese_rock_music_groups'],
#  776470: ['Tzadik_Records_artists'],
#  803399: ['Japanese_rock_music_groups'],
#  837951: ['Japanese_rock_music_groups'],
#  892984: ['Sony_Music_Japan_artists'],
#  893295: ['Japanese_rock_music_groups'],
#  930693: ['Japanese_rock_music_groups'],
#  941824: ['Japanese_rock_music_groups'],
#  968888: ['Japanese_rock_music_groups'],
#  994965: ['Japanese_rock_music_groups'],
#  1015175: ['Japanese_rock_music_groups'],
#  1071413: ['Japanese_rock_music_groups'],
#  1074528: ['Musical_trios'],
#  1172840: ['Japanese_rock_music_groups'],
#  1180772: ['Sony_Music_Japan_artists'],
#  1189675: ['Japanese_rock_music_groups'],
#  1191705: ['Sony_Music_Japan_artists'],
#  1191722: ['Sony_Music_Japan_artists'],
#  1191729: ['Japanese_musical_groups'],
#  1191773: ['Sony_Music_Japan_artists'],
#  1191793: ['Japanese_rock_music_groups'],
#  1191802: ['All-female_bands'],
#  1191803: ['Sony_Music_Japan_artists'],
#  1191830: ['Sony_Music_Japan_artists'],
#  1191834: ['Japanese_rock_music_groups'],
#  1191846: ['Japanese_rock_music_groups'],
#  1191865: ['Japanese_rock_music_groups'],
#  1191872: ['Japanese_rock_music_groups'],
#  1191892: ['Musical_quartets'],
#  1191894: ['Japanese_rock_music_groups'],
#  1191968: ['Musical_quartets'],
#  1191982: ['Japanese_rock_music_groups'],
#  1200999: ['Japanese_rock_music_groups'],
#  1201661: ['Japanese_rock_music_groups'],
#  1223001: ['Japanese_rock_music_groups'],
#  1223386: ['Japanese_rock_music_groups'],
#  1228101: ['Garage_punk'],
#  1228765: ['Japanese_rock_music_groups'],
#  1230067: ['Japanese_rock_music_groups'],
#  1287627: ['Japanese_rock_music_groups'],
#  1291827: ['Sony_Music_Japan_artists'],
#  1316303: ['Japanese_rock_music_groups'],
#  1316323: ['Sony_Music_Japan_artists'],
#  1316336: ['Japanese_rock_music_groups'],
#  1338983: ['Japanese_rock_music_groups'],
#  1365308: ['All-female_bands'],
#  1371483: ['Japanese_musical_groups'],
#  1378964: ['Japanese_rock_music_groups'],
#  1429259: ['Japanese_rock_music_groups'],
#  1450748: ['Sony_Music_Japan_artists'],
#  1469725: ['Japanese_rock_music_groups'],
#  1471827: ['Musical_quartets'],
#  1471852: ['Japanese_rock_music_groups'],
#  1480239: ['Sony_Music_Japan_artists'],
#  1514308: ['Japanese_rock_music_groups'],
#  1514474: ['Musical_quartets'],
#  1550997: ['Japanese_rock_music_groups'],
#  1558831: ['Japanese_rock_music_groups'],
#  1559530: ['Japanese_rock_music_groups'],
#  1559624: ['Japanese_rock_music_groups'],
#  1569632: ['Japanese_musicians'],
#  1584034: ['Japanese_rock_music_groups'],
#  1603244: ['Musical_groups_established_in_1986'],
#  1603704: ['Japanese_rock_music_groups'],
#  1624678: ['Japanese_rock_music_groups'],
#  1626820: ['All-female_bands'],
#  1627203: ['Japanese_rock_music_groups'],
#  1627205: ['People_from_Kanagawa_Prefecture'],
#  1627232: ['Japanese_rock_music_groups'],
#  1627235: ['Japanese_rock_music_groups'],
#  1689739: ['Japanese_rock_music_groups'],
#  1717461: ['Japanese_rock_music_groups'],
#  1720375: ['Japanese_rock_music_groups'],
#  1742964: ['Japanese_rock_music_groups'],
#  1745126: ['Musical_sextets'],
#  1747547: ['Japanese_musical_groups'],
#  1747565: ['Japanese_rock_music_groups'],
#  1747644: ['Japanese_rock_music_groups'],
#  1747919: ['Musical_trios'],
#  1747921: ['Japanese_rock_music_groups'],
#  1747926: ['Japanese_rock_music_groups'],
#  1748616: ['American_rock_music_groups'],
#  1749160: ['Japanese_rock_music_groups'],
#  1749503: ['Japanese_rock_music_groups'],
#  1750117: ['Musical_trios'],
#  1750118: ['Japanese_musical_groups'],
#  1754829: ['Japanese_rock_music_groups'],
#  1754956: ['Japanese_rock_music_groups'],
#  1758209: ['Japanese_rock_music_groups'],
#  1758884: ['Japanese_rock_music_groups'],
#  1759782: ['Living_people'],
#  1789458: ['Japanese_musical_groups'],
#  1941: ['Laboulbeniomycetes'],
#  1942: ['Laboulbeniomycetes'],
#  1943: ['Laboulbeniomycetes'],
#  1944: ['Laboulbeniomycetes'],
#  1945: ['Monotypic_fungi_genera'],
#  1947: ['Laboulbeniomycetes'],
#  1948: ['Laboulbeniomycetes'],
#  1949: ['Laboulbeniomycetes'],
#  1950: ['Laboulbeniomycetes'],
#  1951: ['Laboulbeniomycetes'],
#  1952: ['Laboulbeniomycetes'],
#  1953: ['Laboulbeniomycetes'],
#  1954: ['Laboulbeniomycetes'],
#  1955: ['Laboulbeniomycetes'],
#  1956: ['Laboulbeniomycetes'],
#  1957: ['Laboulbeniomycetes'],
#  1958: ['Laboulbeniomycetes'],
#  1959: ['Monotypic_fungi_genera'],
#  1960: ['Monotypic_fungi_genera'],
#  1961: ['Laboulbeniomycetes'],
#  1962: ['Monotypic_fungi_genera'],
#  ...}

# %%
"""
Finally, we create a last dictionary that takes us back to the initial state, i.e. 
the name of the category and the pages (integers) in that category. 
This time, each page is linked to a single category.
"""

categories_red = {}
for key, elem in tqdm(one_cat_per_pages.items()):

    if elem[0] not in categories_red:
            a= []
            a.append(key)
            categories_red[elem[0]]=a
    else: 
            aux = list(categories_red[elem[0]])
            aux.append(key)
            categories_red[elem[0]]= aux
# Out:
# 100%|██████████| 1791489/1791489 [04:55<00:00, 6070.61it/s]

# %%
write_pickle('data/categories_red.pkl', categories_red)

# %%
categories_red  = read_pickle('data/categories_red.pkl')

# %%
categories_red
# Out:
# {'Buprestoidea': [301,
#   302,
#   303,
#   304,
#   305,
#   306,
#   307,
#   308,
#   309,
#   310,
#   311,
#   312,
#   313,
#   314,
#   315,
#   316,
#   317,
#   318,
#   319,
#   320,
#   321,
#   322,
#   323,
#   324,
#   325,
#   326,
#   327,
#   328,
#   329,
#   330,
#   331,
#   332,
#   333,
#   334,
#   335,
#   336,
#   337,
#   338,
#   339,
#   340,
#   341,
#   342,
#   343,
#   344,
#   345,
#   346,
#   347,
#   348,
#   349,
#   350,
#   351,
#   352,
#   353,
#   354,
#   355,
#   356,
#   357,
#   358,
#   359,
#   360,
#   361,
#   362,
#   363,
#   364,
#   365,
#   366,
#   367,
#   368,
#   369,
#   370,
#   371,
#   372,
#   373,
#   374,
#   375,
#   376,
#   377,
#   378,
#   379,
#   380,
#   381,
#   382,
#   383,
#   384,
#   385,
#   386,
#   387,
#   388,
#   389,
#   390,
#   391,
#   392,
#   393,
#   394,
#   395,
#   396,
#   397,
#   398,
#   399,
#   400,
#   401,
#   402,
#   403,
#   404,
#   405,
#   406,
#   407,
#   408,
#   409,
#   410,
#   411,
#   412,
#   413,
#   414,
#   415,
#   416,
#   417,
#   418,
#   419,
#   420,
#   421,
#   422,
#   423,
#   424,
#   425,
#   426,
#   427,
#   428,
#   429,
#   430,
#   431,
#   432,
#   433,
#   434,
#   435,
#   436,
#   437,
#   438,
#   439,
#   440,
#   441,
#   442,
#   443,
#   444,
#   445,
#   446,
#   447,
#   448,
#   449,
#   450,
#   451,
#   452,
#   453,
#   454,
#   455,
#   456,
#   457,
#   458,
#   459,
#   460,
#   461,
#   462,
#   463,
#   464,
#   465,
#   466,
#   467,
#   468,
#   469,
#   470,
#   471,
#   472,
#   473,
#   474,
#   475,
#   476,
#   477,
#   478,
#   479,
#   480,
#   481,
#   482,
#   483,
#   484,
#   485,
#   486,
#   487,
#   488,
#   489,
#   490,
#   491,
#   492,
#   493,
#   494,
#   495,
#   496,
#   497,
#   498,
#   499,
#   500,
#   501,
#   502,
#   503,
#   504,
#   505,
#   506,
#   507,
#   508,
#   509,
#   510,
#   511,
#   512,
#   513,
#   514,
#   515,
#   516,
#   517,
#   518,
#   519,
#   520,
#   521,
#   522,
#   523,
#   524,
#   525,
#   526,
#   527,
#   528,
#   529,
#   530,
#   531,
#   532,
#   533,
#   534,
#   535,
#   536,
#   537,
#   538,
#   539,
#   540,
#   541,
#   542,
#   543,
#   544,
#   545,
#   546,
#   547,
#   548,
#   549,
#   550,
#   551,
#   552,
#   553,
#   554,
#   555,
#   556,
#   557,
#   558,
#   559,
#   560,
#   561,
#   562,
#   563,
#   564,
#   565,
#   566,
#   567,
#   568,
#   569,
#   570,
#   571,
#   572,
#   573,
#   574,
#   575,
#   576,
#   577,
#   578,
#   579,
#   580,
#   581,
#   582,
#   583,
#   584,
#   585,
#   586,
#   587,
#   588,
#   589,
#   590,
#   591,
#   592,
#   593,
#   594,
#   595,
#   596,
#   597,
#   598,
#   599,
#   600,
#   601,
#   602,
#   603,
#   604,
#   605,
#   606,
#   607,
#   608,
#   609,
#   610,
#   611,
#   612,
#   613,
#   614,
#   615,
#   616,
#   617,
#   618,
#   619,
#   620,
#   621,
#   622,
#   623,
#   624,
#   625,
#   626,
#   627,
#   628,
#   629,
#   630,
#   631,
#   632,
#   633,
#   634,
#   635,
#   636,
#   637,
#   638,
#   639,
#   640,
#   641,
#   642,
#   643,
#   644,
#   645,
#   646,
#   647,
#   648,
#   649,
#   650,
#   651,
#   652,
#   653,
#   654,
#   655,
#   656,
#   657,
#   658,
#   659,
#   660,
#   661,
#   662,
#   663,
#   664,
#   665,
#   666,
#   667,
#   668,
#   669,
#   670,
#   671,
#   672,
#   673,
#   674,
#   675,
#   676,
#   677,
#   678,
#   679,
#   680,
#   681,
#   682,
#   683,
#   684,
#   685,
#   686,
#   687,
#   688,
#   689,
#   690,
#   691,
#   692,
#   693,
#   694,
#   695,
#   696,
#   697,
#   698,
#   699,
#   700,
#   701,
#   702,
#   703,
#   704,
#   705,
#   706,
#   707,
#   708,
#   709,
#   710,
#   711,
#   712,
#   713,
#   714,
#   715,
#   716,
#   717,
#   718,
#   719,
#   720,
#   721,
#   722,
#   723,
#   724,
#   725,
#   726,
#   727,
#   728,
#   729,
#   730,
#   731,
#   732,
#   733,
#   734,
#   735,
#   736,
#   737,
#   738,
#   739,
#   740,
#   741,
#   742,
#   743,
#   744,
#   745,
#   746,
#   747,
#   748,
#   749,
#   750,
#   751,
#   752,
#   753,
#   754,
#   755,
#   756,
#   757,
#   758,
#   759,
#   760,
#   761,
#   762,
#   763,
#   764,
#   765,
#   766,
#   767,
#   768,
#   769,
#   770,
#   771,
#   772,
#   773,
#   774,
#   775,
#   776,
#   777,
#   778,
#   779,
#   780,
#   781,
#   782,
#   783,
#   784,
#   785,
#   786,
#   787,
#   788,
#   789,
#   790,
#   791,
#   792,
#   793,
#   794,
#   795,
#   796,
#   797,
#   798,
#   799,
#   800,
#   801,
#   802,
#   803,
#   804,
#   805,
#   806,
#   807,
#   808,
#   809,
#   810,
#   811,
#   812,
#   813,
#   814,
#   815,
#   816,
#   817,
#   818,
#   819,
#   820,
#   821,
#   822,
#   823,
#   824,
#   825,
#   826,
#   827,
#   828,
#   829,
#   830,
#   831,
#   832,
#   833,
#   834,
#   835,
#   836,
#   837,
#   838,
#   839,
#   840,
#   841,
#   842,
#
#   139857,
#   190762,
#   190807,
#   190809,
#   191121,
#   191124,
#   191256,
#   191437,
#   191627,
#   191669,
#   191795,
#   191974,
#   191975,
#   366041,
#   366237,
#   366366,
#   370179,
#   370265,
#   395231,
#   395232,
#   395338,
#   395370,
#   395392,
#   416849,
#   417017,
#   417104,
#   417270,
#   436111,
#   436127,
#   436167,
#   436184,
#   438646,
#   443454,
#   443523,
#   443526,
#   443560,
#   443690,
#   443711,
#   443754,
#   443787,
#   443792,
#   443855,
#   443857,
#   460812,
#   460910,
#   460952,
#   460982,
#   461023,
#   496630,
#   496644,
#   496670,
#   496690,
#   496702,
#   496785,
#   529628,
#   569526,
#   569539,
#   570997,
#   579600,
#   580710,
#   580719,
#   621233,
#   622093,
#   622813,
#   622821,
#   622922,
#   623096,
#   623162,
#   623210,
#   623349,
#   623359,
#   623360,
#   623945,
#   672784,
#   683409,
#   683619,
#   683692,
#   683795,
#   683812,
#   683899,
#   684010,
#   684113,
#   684225,
#   684236,
#   684478,
#   684920,
#   719240,
#   719241,
#   719270,
#   719274,
#   719275,
#   728310,
#   728316,
#   728374,
#   728382,
#   728523,
#   728664,
#   728689,
#   728697,
#   728793,
#   728885,
#   734256,
#   734313,
#   734329,
#   734359,
#   734458,
#   734465,
#   734508,
#   734524,
#   734532,
#   734592,
#   734660,
#   734813,
#   735180,
#   735201,
#   735343,
#   735384,
#   735441,
#   735449,
#   735638,
#   735662,
#   735742,
#   735807,
#   735851,
#   735908,
#   735911,
#   736000,
#   736050,
#   736063,
#   736077,
#   736236,
#   736271,
#   736372,
#   736407,
#   736457,
#   736688,
#   736763,
#   736772,
#   736915,
#   736923,
#   736926,
#   736929,
#   736959,
#   736975,
#   736976,
#   737053,
#   737135,
#   737155,
#   737228,
#   737309,
#   737389,
#   737511,
#   737568,
#   737721,
#   737732,
#   737757,
#   737857,
#   737947,
#   738007,
#   738023,
#   738069,
#   738250,
#   738265,
#   738382,
#   738506,
#   738550,
#   738582,
#   738601,
#   738691,
#   738715,
#   738739,
#   738748,
#   738763,
#   738774,
#   743255,
#   772273,
#   790880,
#   791180,
#   791205,
#   802955,
#   803000,
#   803060,
#   803075,
#   803098,
#   803266,
#   803328,
#   884792,
#   884830,
#   885077,
#   885080,
#   886466,
#   886519,
#   886522,
#   886552,
#   893764,
#   893879,
#   894113,
#   894173,
#   894214,
#   894223,
#   894226,
#   894250,
#   894271,
#   894339,
#   894581,
#   894644,
#   894742,
#   895111,
#   895202,
#   895251,
#   895352,
#   895402,
#   895453,
#   895657,
#   895687,
#   895855,
#   895965,
#   896060,
#   896164,
#   896357,
#   896363,
#   896522,
#   896625,
#   896704,
#   930559,
#   943876,
#   1001815,
#   1001835,
#   1001836,
#   1001839,
#   1001859,
#   1001866,
#   1001867,
#   1001876,
#   1001879,
#   1001885,
#   1004102,
#   1004233,
#   1004366,
#   1004683,
#   1004704,
#   1004710,
#   1004748,
#   1004794,
#   1004852,
#   1004985,
#   1005017,
#   1005280,
#   1005579,
#   1005722,
#   1423383,
#   1431841,
#   1442476,
#   1479297,
#   1482491,
#   1495125,
#   1500630,
#   1511661,
#   1533228,
#   1553284,
#   1621553,
#   1623053,
#   1636181,
#   1662052,
#   1671609,
#   1679572,
#   1713371,
#   1715908,
#   1716105,
#   1720256,
#   1724852,
#   1774736,
#   1061503,
#   1291507,
#   1400739,
#   288152,
#   392239,
#   1572384,
#   250846,
#   821389,
#   766912,
#   256252,
#   318970,
#   1409669,
#   315717,
#   733834,
#   1729499,
#   275325,
#   1414753,
#   47772,
#   318354,
#   327029,
#   1089566,
#   1705213,
#   318803,
#   1098929,
#   1163933,
#   148983,
#   318644,
#   318789,
#   318876,
#   318905,
#   1131654,
#   1169901,
#   318467,
#   318878,
#   318366,
#   318784,
#   318981,
#   1504134,
#   318881,
#   318498,
#   318779,
#   318887,
#   231181,
#   318929,
#   12341,
#   35533,
#   46847,
#   108457,
#   108525,
#   115091,
#   251303,
#   300497,
#   315603,
#   315664,
#   318298,
#   318327,
#   318838,
#   318843,
#   318849,
#   318855,
#   318856,
#   318930,
#   318942,
#   318965,
#   318991,
#   319013,
#   325903,
#   340025,
#   340362,
#   349934,
#   350569,
#   404852,
#   466716,
#   484202,
#   580673,
#   596424,
#   613019,
#   679584,
#   698379,
#   698884,
#   765089,
#   807614,
#   815416,
#   824657,
#   839878,
#   866404,
#   922850,
#   924275,
#   925373,
#   925932,
#   943936,
#   962334,
#   968963,
#   973287,
#   973456,
#   976274,
#   1021625,
#   1021633,
#   1048600,
#   1139478,
#   1201694,
#   1234965,
#   1262708,
#   1263094,
#   1267774,
#   1283559,
#   1301263,
#   1320190,
#   1401714,
#   1405342,
#   1416467,
#   1416738,
#   1425885,
#   1446115,
#   1448845,
#   1479718,
#   1490237,
#   1495243,
#   1533414,
#   1633425,
#   1637093,
#   1639677,
#   1661825,
#   1714445,
#   1715312,
#   1724875],
#  'American_non-fiction_environmental_writers': [1234416,
#   1235114,
#   324112,
#   821670,
#   598069,
#   46846,
#   64265,
#   136966,
#   263675,
#   514701,
#   599004,
#   633813,
#   656658,
#   1077640,
#   1234723,
#   1235009,
#   1235118,
#   1530860,
#   1715128,
#   53689,
#   1637263,
#   1234739],
#  'American_geographers': [1234902,
#   406269,
#   767593,
#   406222,
#   406237,
#   406262,
#   406277,
#   406280,
#   406312,
#   1077571,
#   1298824,
#   1382352,
#   1511087,
#   1762848,
#   38893,
#   451300,
#   1283141,
#   924265,
#   406203,
#   311648,
#   406246,
#   406250,
#   406281,
#   406290,
#   406304,
#   406377,
#   455125],
#  'American_Marxists': [1235152,
#   598055,
#   1636541,
#   821262,
#   821465,
#   599777,
#   599929,
#   67156,
#   66930,
#   1714964,
#   467989,
#   601610,
#   817315,
#   931945,
#   599828,
#   599903,
#   1636564,
#   600011,
#   599882,
#   599550,
#   599805,
#   1173032,
#   599830,
#   599849,
#   599834,
#   599947,
#   825064,
#   1637249,
#   598785,
#   599769,
#   599784,
#   599827,
#   599846,
#   599974,
#   1364358,
#   1426472],
#  ...}
